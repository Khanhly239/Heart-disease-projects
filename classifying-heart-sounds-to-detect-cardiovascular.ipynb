# %% [markdown]
# ## **Data Exploratory Analysis**

# %%
import pandas as pd
import librosa as lr
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
from sklearn.utils import resample
import seaborn as sns
from sklearn.model_selection import train_test_split
import os, fnmatch

# %%
ROOT = '/kaggle/input/heartbeat-sounds'

# %%
acsv = ROOT +'/set_a.csv'
bcsv = ROOT + '/set_b.csv'

# %%
setA = pd.read_csv(acsv)
setB = pd.read_csv(bcsv)

# %% [markdown]
# Understanding the data

# %%
print(setA.head(-1))
# Out:
#     dataset                             fname     label  sublabel
# 0         a  set_a/artifact__201012172012.wav  artifact       NaN
# 1         a  set_a/artifact__201105040918.wav  artifact       NaN
# 2         a  set_a/artifact__201105041959.wav  artifact       NaN
# 3         a  set_a/artifact__201105051017.wav  artifact       NaN
# 4         a  set_a/artifact__201105060108.wav  artifact       NaN
# ..      ...                               ...       ...       ...
# 170       a          set_a/__201108222234.wav       NaN       NaN
# 171       a          set_a/__201108222241.wav       NaN       NaN
# 172       a          set_a/__201108222244.wav       NaN       NaN
# 173       a          set_a/__201108222247.wav       NaN       NaN
# 174       a          set_a/__201108222254.wav       NaN       NaN
#
# [175 rows x 4 columns]

# %%
print(setB.head(-1))
# Out:
#     dataset                                              fname       label  \
# 0         b  set_b/Btraining_extrastole_127_1306764300147_C...  extrastole
# 1         b  set_b/Btraining_extrastole_128_1306344005749_A...  extrastole
# 2         b  set_b/Btraining_extrastole_130_1306347376079_D...  extrastole
# 3         b  set_b/Btraining_extrastole_134_1306428161797_C...  extrastole
# 4         b  set_b/Btraining_extrastole_138_1306762146980_B...  extrastole
# ..      ...                                                ...         ...
# 650       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 651       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 652       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 653       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 654       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
#
#         sublabel
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 650  noisynormal
# 651  noisynormal
# 652  noisynormal
# 653  noisynormal
# 654  noisynormal
#
# [655 rows x 4 columns]

# %%
setA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dataset   176 non-null    object
#  1   fname     176 non-null    object
#  2   label     124 non-null    object
#  3   sublabel  0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 5.6+ KB

# %%
setB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dataset   656 non-null    object
#  1   fname     656 non-null    object
#  2   label     461 non-null    object
#  3   sublabel  149 non-null    object
# dtypes: object(4)
# memory usage: 20.6+ KB

# %%
setB.describe()
# Out:
#        dataset                                              fname   label  \
# count      656                                                656     461
# unique       1                                                656       3
# top          b  set_b/Btraining_extrastole_127_1306764300147_C...  normal
# freq       656                                                  1     320
#
#            sublabel
# count           149
# unique            2
# top     noisynormal
# freq            120

# %%
print(setA["label"].value_counts())
# Out:
# artifact    40
# murmur      34
# normal      31
# extrahls    19
# Name: label, dtype: int64

# %%
print(setA["label"].value_counts().sum())
# Out:
# 124

# %%
print(setA["label"].isnull().sum())
# Out:
# 52

# %% [markdown]
# Editing the data

# %%
# we will drop the entries with artifact as label since it is not one of the needed classifications
setA = setA[setA.label != 'artifact']

# %%
# we will drop the entries with null as the label
setA = setA.dropna(subset=['label'])
setA.head(-1)
# Out:
#     dataset                             fname     label  sublabel
# 40        a  set_a/extrahls__201101070953.wav  extrahls       NaN
# 41        a  set_a/extrahls__201101091153.wav  extrahls       NaN
# 42        a  set_a/extrahls__201101152255.wav  extrahls       NaN
# 43        a  set_a/extrahls__201101160804.wav  extrahls       NaN
# 44        a  set_a/extrahls__201101160808.wav  extrahls       NaN
# ..      ...                               ...       ...       ...
# 118       a    set_a/normal__201106221418.wav    normal       NaN
# 119       a    set_a/normal__201106221450.wav    normal       NaN
# 120       a    set_a/normal__201108011112.wav    normal       NaN
# 121       a    set_a/normal__201108011114.wav    normal       NaN
# 122       a    set_a/normal__201108011115.wav    normal       NaN
#
# [83 rows x 4 columns]

# %%
print(setA["label"].value_counts())
# now set A has 3 classifications
# Out:
# murmur      34
# normal      31
# extrahls    19
# Name: label, dtype: int64

# %%
# we will drop the entries with null as the label
setB = setB.dropna(subset=['label'])
setB.head(-1)
# Out:
#     dataset                                              fname       label  \
# 0         b  set_b/Btraining_extrastole_127_1306764300147_C...  extrastole
# 1         b  set_b/Btraining_extrastole_128_1306344005749_A...  extrastole
# 2         b  set_b/Btraining_extrastole_130_1306347376079_D...  extrastole
# 3         b  set_b/Btraining_extrastole_134_1306428161797_C...  extrastole
# 4         b  set_b/Btraining_extrastole_138_1306762146980_B...  extrastole
# ..      ...                                                ...         ...
# 650       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 651       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 652       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 653       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
# 654       b  set_b/Btraining_normal_Btraining_noisynormal_2...      normal
#
#         sublabel
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 650  noisynormal
# 651  noisynormal
# 652  noisynormal
# 653  noisynormal
# 654  noisynormal
#
# [460 rows x 4 columns]

# %%
print(setB["label"].value_counts())
# set B has 3 classifications
# Out:
# normal        320
# murmur         95
# extrastole     46
# Name: label, dtype: int64

# %%
# will need all 4 categories together to be able to classify, so will join both sets A and B
setAB = [setA,setB]
ABdf = pd.concat(setAB)
print(ABdf.head(-1))
# Out:
#     dataset                                              fname     label  \
# 40        a                   set_a/extrahls__201101070953.wav  extrahls
# 41        a                   set_a/extrahls__201101091153.wav  extrahls
# 42        a                   set_a/extrahls__201101152255.wav  extrahls
# 43        a                   set_a/extrahls__201101160804.wav  extrahls
# 44        a                   set_a/extrahls__201101160808.wav  extrahls
# ..      ...                                                ...       ...
# 650       b  set_b/Btraining_normal_Btraining_noisynormal_2...    normal
# 651       b  set_b/Btraining_normal_Btraining_noisynormal_2...    normal
# 652       b  set_b/Btraining_normal_Btraining_noisynormal_2...    normal
# 653       b  set_b/Btraining_normal_Btraining_noisynormal_2...    normal
# 654       b  set_b/Btraining_normal_Btraining_noisynormal_2...    normal
#
#         sublabel
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# ..           ...
# 650  noisynormal
# 651  noisynormal
# 652  noisynormal
# 653  noisynormal
# 654  noisynormal
#
# [544 rows x 4 columns]

# %%
print(ABdf["label"].value_counts())
# Out:
# normal        351
# murmur        129
# extrastole     46
# extrahls       19
# Name: label, dtype: int64

# %% [markdown]
# Distribution of each class

# %%
ABdf['label'].hist(figsize=(5, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# The data is very unbalanced, so we will upsample extrahls and extrastole and downsample normal

# %%
df_murmur = ABdf[ABdf.label == 'murmur']
df_extrastole = ABdf[ABdf.label == 'extrastole']
df_extrahls = ABdf[ABdf.label == 'extrahls']
df_normal = ABdf[ABdf.label == 'normal']
 
# Upsample minority classes
df_exhals_upsampled = resample(df_extrahls, replace=True, n_samples=129)    # to match murmur class
df_extrastole_upsampled = resample(df_extrastole, replace=True, n_samples=129)
# Downsample majority class
df_normal_downsampled = resample(df_normal, replace=False, n_samples=129)                               

# Combine classes
df_upsampled = pd.concat([df_murmur, df_exhals_upsampled])
df_upsampled = pd.concat([df_upsampled, df_extrastole_upsampled])
ABdf = pd.concat([df_upsampled, df_normal_downsampled])

ABdf.label.value_counts()
# Out:
# murmur        129
# extrahls      129
# extrastole    129
# normal        129
# Name: label, dtype: int64

# %%
ABdf['label'].hist(figsize=(5, 5))
# Out:
# <AxesSubplot:>

# %%
ABdf.head(-1)
# Out:
#     dataset                                            fname   label sublabel
# 59        a                   set_a/murmur__201101051104.wav  murmur      NaN
# 60        a                   set_a/murmur__201101051108.wav  murmur      NaN
# 61        a                   set_a/murmur__201101051114.wav  murmur      NaN
# 62        a                   set_a/murmur__201101180902.wav  murmur      NaN
# 63        a                   set_a/murmur__201102051443.wav  murmur      NaN
# ..      ...                                              ...     ...      ...
# 259       b  set_b/Btraining_normal_218_1308246311449_C1.wav  normal      NaN
# 261       b   set_b/Btraining_normal_220_1308250132896_D.wav  normal      NaN
# 236       b   set_b/Btraining_normal_201_1308144942432_A.wav  normal      NaN
# 223       b   set_b/Btraining_normal_183_1308072703477_C.wav  normal      NaN
# 146       b   set_b/Btraining_normal_137_1306764999211_D.wav  normal      NaN
#
# [515 rows x 4 columns]

# %%
ABdf = ABdf.reset_index()
print(ABdf.head(-1))
# Out:
#      index dataset                                            fname   label  \
# 0       59       a                   set_a/murmur__201101051104.wav  murmur
# 1       60       a                   set_a/murmur__201101051108.wav  murmur
# 2       61       a                   set_a/murmur__201101051114.wav  murmur
# 3       62       a                   set_a/murmur__201101180902.wav  murmur
# 4       63       a                   set_a/murmur__201102051443.wav  murmur
# ..     ...     ...                                              ...     ...
# 510    259       b  set_b/Btraining_normal_218_1308246311449_C1.wav  normal
# 511    261       b   set_b/Btraining_normal_220_1308250132896_D.wav  normal
# 512    236       b   set_b/Btraining_normal_201_1308144942432_A.wav  normal
# 513    223       b   set_b/Btraining_normal_183_1308072703477_C.wav  normal
# 514    146       b   set_b/Btraining_normal_137_1306764999211_D.wav  normal
#
#     sublabel
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 510      NaN
# 511      NaN
# 512      NaN
# 513      NaN
# 514      NaN
#
# [515 rows x 5 columns]

# %% [markdown]
# Looking at the audio signals of each class

# %%
dir = ROOT + '/'

# %%
# making a new dataframe with just the audio and its label
audioList = []
labels = []
for j in range(516):
  if('Btraining_extrastole' in ABdf['fname'][j]):
    alteredPathName = ABdf['fname'][j].replace('Btraining_extrastole', 'extrastole_')
    #print(alteredPathName)
    audioList.append(dir + alteredPathName)
    labels.append(ABdf["label"][j])
  elif('Btraining_normal_Btraining_' in ABdf['fname'][j]):
    alteredPathName = ABdf['fname'][j].replace('Btraining_normal_Btraining_', 'normal_')
    audioList.append(dir + alteredPathName)
    labels.append(ABdf["label"][j])
  elif('Btraining_normal' in ABdf['fname'][j]):
    alteredPathName = ABdf['fname'][j].replace('Btraining_normal', 'normal_')
    audioList.append(dir + alteredPathName)
    labels.append(ABdf["label"][j])
  elif('Btraining_murmur_Btraining_' in ABdf['fname'][j]):
    alteredPathName = ABdf['fname'][j].replace('Btraining_murmur_Btraining_', 'murmur_')
    audioList.append(dir + alteredPathName)
    labels.append(ABdf["label"][j])
  elif('Btraining_murmur' in ABdf['fname'][j]):
    alteredPathName = ABdf['fname'][j].replace('Btraining_murmur', 'murmur_')
    audioList.append(dir + alteredPathName)
    labels.append(ABdf["label"][j])
  else:
    audioList.append(dir + str(ABdf["fname"][j]))
    labels.append(ABdf["label"][j])

# %%
print(audioList)
print(len(audioList))
print(len(labels))
# Out:
# ['/kaggle/input/heartbeat-sounds/set_a/murmur__201101051104.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201101051108.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201101051114.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201101180902.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201102051443.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201102052338.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201103291548.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201104021355.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201104241315.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201104291843.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201106141148.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222221.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222223.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222224.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222226.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222227.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222231.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222232.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222233.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222235.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222236.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222237.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222238.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222242.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222243.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222245.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222246.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222248.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222251.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222252.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222253.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222255.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222256.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222258.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__112_1306243000964_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__112_1306243000964_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__112_1306243000964_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__116_1306258689913_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__116_1306258689913_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__116_1306258689913_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__122_1306325762831_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__122_1306325762831_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__156_1306936373241_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__160_1307100683334_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__160_1307100683334_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__161_1307101199321_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__162_1307101835989_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__162_1307101835989_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__164_1307106095995_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__164_1307106095995_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__165_1307109069581_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__165_1307109069581_C2.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__171_1307971016233_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__171_1307971016233_D1.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__171_1307971016233_E.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__185_1308073325396_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__185_1308073325396_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__193_1308078104592_B.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__193_130807810 ...
# 516
# 516

# %%
audioListSeries = pd.Series(audioList,name="Audio")
labelsSeries = pd.Series(labels,name="Label")
audioDF = pd.concat([audioListSeries,labelsSeries],axis=1)

# %%
audioDF['Label'].value_counts()
# Out:
# murmur        129
# extrahls      129
# extrastole    129
# normal        129
# Name: Label, dtype: int64

# %%
audioDF.head(-1)
# Out:
#                                                  Audio   Label
# 0    /kaggle/input/heartbeat-sounds/set_a/murmur__2...  murmur
# 1    /kaggle/input/heartbeat-sounds/set_a/murmur__2...  murmur
# 2    /kaggle/input/heartbeat-sounds/set_a/murmur__2...  murmur
# 3    /kaggle/input/heartbeat-sounds/set_a/murmur__2...  murmur
# 4    /kaggle/input/heartbeat-sounds/set_a/murmur__2...  murmur
# ..                                                 ...     ...
# 510  /kaggle/input/heartbeat-sounds/set_b/normal__2...  normal
# 511  /kaggle/input/heartbeat-sounds/set_b/normal__2...  normal
# 512  /kaggle/input/heartbeat-sounds/set_b/normal__2...  normal
# 513  /kaggle/input/heartbeat-sounds/set_b/normal__1...  normal
# 514  /kaggle/input/heartbeat-sounds/set_b/normal__1...  normal
#
# [515 rows x 2 columns]

# %%
i = 0
while('extrahls' not in audioDF['Audio'][i]):
  i+=1
print(audioDF['Audio'][i])
print(i)

audio, audio_sfreq = lr.load(audioDF['Audio'][i], duration=5)
time = np.arange(0, len(audio)) / audio_sfreq
# Plot audio over time
fig, ax = plt.subplots()
ax.plot(time, audio)
ax.set(xlabel='Time (s)', ylabel='Sound Amplitude')
ax.set_title('Extrahls heartbeat')
plt.show()
Audio(audio,rate=audio_sfreq)
# Out:
# /kaggle/input/heartbeat-sounds/set_a/extrahls__201103182227.wav
# 129
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dur=lr.get_duration(audio)
print ("duration:", dur)
print(audio.shape, audio_sfreq)
# Out:
# duration: 5.0
# (110250,) 22050
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Pass y=[-4.3862474e-05  8.4505627e-05  1.3877093e-04 ...  5.6488789e-03
#   6.1442689e-03  7.1542142e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   """Entry point for launching an IPython kernel.

# %%
i = 0
while('murmur' not in audioDF['Audio'][i]):
  i+=1
print(audioDF['Audio'][i])
print(i)

audio, audio_sfreq = lr.load(audioDF['Audio'][i], duration=5)
time = np.arange(0, len(audio)) / audio_sfreq
# Plot audio over time
fig, ax = plt.subplots()
ax.plot(time, audio)
ax.set(xlabel='Time (s)', ylabel='Sound Amplitude')
ax.set_title('Murmur heartbeat')
plt.show()
Audio(audio,rate=audio_sfreq)
#print(audio,audio_sfreq)
# Out:
# /kaggle/input/heartbeat-sounds/set_a/murmur__201101051104.wav
# 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dur=lr.get_duration(audio)
print ("duration:", dur)
print(audio.shape, audio_sfreq)
# Out:
# duration: 5.0
# (110250,) 22050
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Pass y=[-0.00529056 -0.00752499 -0.00610133 ...  0.00093688  0.00056159
#   0.00031823] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   """Entry point for launching an IPython kernel.

# %%
i = 0
while('normal' not in audioDF['Audio'][i]):
  i+=1
print(audioDF['Audio'][i])
print(i)

audio, audio_sfreq = lr.load(audioDF['Audio'][i], duration=5)
time = np.arange(0, len(audio)) / audio_sfreq
# Plot audio over time
fig, ax = plt.subplots()
ax.plot(time, audio)
ax.set(xlabel='Time (s)', ylabel='Sound Amplitude')
ax.set_title('Normal heartbeat')
plt.show()
Audio(audio,rate=audio_sfreq)
# Out:
# /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_271_1309369876160_C.wav
# 387
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dur=lr.get_duration(audio)
print ("duration:", dur)
print(audio.shape, audio_sfreq)
# Out:
# duration: 5.0
# (110250,) 22050
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Pass y=[-7.6404610e-03 -8.1271231e-03 -8.1920139e-03 ...  4.0253206e-05
#   4.6381949e-05  1.7020293e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   """Entry point for launching an IPython kernel.

# %%
i = 0
while('extrastole' not in audioDF['Audio'][i]):
  i+=1
print(audioDF['Audio'][i])
print(i)

audio, audio_sfreq = lr.load(audioDF['Audio'][i], duration=5)
time = np.arange(0, len(audio)) / audio_sfreq
# Plot audio over time
fig, ax = plt.subplots()
ax.plot(time, audio)
ax.set(xlabel='Time (s)', ylabel='Sound Amplitude')
ax.set_title('Extrastole heartbeat')
plt.show()
Audio(audio,rate=audio_sfreq)
# Out:
# /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B1.wav
# 258
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# function to stretch the time of the signal
def stretch_function(data,rate=0.5):
    return lr.effects.time_stretch(data,rate)

# %%
word = ABdf['fname'][258].replace('Btraining_extrastole', 'extrastole_')
wav_type,sample_rate = lr.load(dir + word)
stretch_audio = stretch_function(wav_type)
Audio(stretch_audio,rate=sample_rate)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass rate=0.5 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Data Splitting**

# %%
Xb = audioDF['Audio']
Yb = audioDF['Label']

# %%
print(Xb)
# Out:
# 0      /kaggle/input/heartbeat-sounds/set_a/murmur__2...
# 1      /kaggle/input/heartbeat-sounds/set_a/murmur__2...
# 2      /kaggle/input/heartbeat-sounds/set_a/murmur__2...
# 3      /kaggle/input/heartbeat-sounds/set_a/murmur__2...
# 4      /kaggle/input/heartbeat-sounds/set_a/murmur__2...
#                              ...
# 511    /kaggle/input/heartbeat-sounds/set_b/normal__2...
# 512    /kaggle/input/heartbeat-sounds/set_b/normal__2...
# 513    /kaggle/input/heartbeat-sounds/set_b/normal__1...
# 514    /kaggle/input/heartbeat-sounds/set_b/normal__1...
# 515    /kaggle/input/heartbeat-sounds/set_b/normal_no...
# Name: Audio, Length: 516, dtype: object

# %%
print(Yb)
# Out:
# 0      murmur
# 1      murmur
# 2      murmur
# 3      murmur
# 4      murmur
#         ...
# 511    normal
# 512    normal
# 513    normal
# 514    normal
# 515    normal
# Name: Label, Length: 516, dtype: object

# %%
x_trainb, x_testb, y_trainb, y_testb = train_test_split(Xb, Yb, train_size=0.85, shuffle=True)
x_trainb, x_valb, y_trainb, y_valb = train_test_split(x_trainb, y_trainb, test_size=0.176, shuffle=True)

# %%
print("x test = " + str(x_testb.size))
print("y test = " + str(y_testb.size))
print("x train = " + str(x_trainb.size))
print("y train = " + str(y_trainb.size))
print("x val = " + str(x_valb.size))
print("y val = " + str(y_valb.size))
# Out:
# x test = 78
# y test = 78
# x train = 360
# y train = 360
# x val = 78
# y val = 78

# %% [markdown]
# ## Data preparation

# %%
MAX_SOUND_CLIP_DURATION = 12

# %%
def load_file_data (file_names, duration=12, sr=22050):
    input_length=sr*duration
    # function to load files and extract features
    data = []    
    for file_name in file_names:
        try:
            sound_file=file_name
            print ("load file ",sound_file)
            X, sr = lr.load( sound_file, sr=sr, duration=duration) 
            dur = lr.get_duration(y=X, sr=sr)
            # pad audio file same duration
            if (round(dur) < duration):
                print ("fixing audio length :", file_name)
                y = lr.util.fix_length(X, input_length)                          
            # extract normalized mfcc feature from data
            mfccs = np.mean(lr.feature.mfcc(y=X, sr=sr, n_mfcc=40).T,axis=0)             
        except Exception as e:
            print("Error encountered while parsing file: ", file_name)        
        feature = np.array(mfccs).reshape([-1,1])
        data.append(feature)
    return data

# %%
FILES = x_trainb.values
x_trainb_pad = load_file_data(file_names=FILES, duration=MAX_SOUND_CLIP_DURATION)
FILES = x_valb.values
X_valb_pad = load_file_data(file_names=FILES, duration=MAX_SOUND_CLIP_DURATION)
FILES = x_testb.values
X_testb_pad = load_file_data(file_names=FILES, duration=MAX_SOUND_CLIP_DURATION)
# Out:
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__164_1307106095995_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__164_1307106095995_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__249_1309202052376_C.wav
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Pass size=264600 as keyword args. From version 0.10 passing these as positional arguments will result in an error
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__249_1309202052376_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270458.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270458.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_216_1308245839516_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101160808.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101160808.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_171_1307971016233_F.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_171_1307971016233_F.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__261_1309353556003_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__261_1309353556003_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/normal__201105021654.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/normal__201105021654.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_155_1306935902813_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_125_1306332456645_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_125_1306332456645_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__242_1309197394064_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__242_1309197394064_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_105_1305033453095_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_105_1305033453095_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__203_1308162026258_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__203_1308162026258_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__116_1306258689913_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__116_1306258689913_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__140_1306519735121_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__140_1306519735121_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__196_1308141034858_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_108_1305654420093_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104021355.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104021355.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__148_1306768801551_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__148_1306768801551_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__293_1311680805936_B1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__293_1311680805936_B1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__235_1308749032454_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__235_1308749032454_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__151_1306779785624_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__151_1306779785624_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_288_1311164615284_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__197_1308141235553_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_161_1307101199321_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_161_1307101199321_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201103150114.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201103150114.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101241433.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101241433.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201104291843.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201104291843.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__274_1311075637574_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__274_1311075637574_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__138_1306762146980_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__138_1306762146980_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__112_1306243000964_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_156_1306936373241_B1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_156_1306936373241_B1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__162_1307101835989_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__162_1307101835989_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__183_1308072703477_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__183_1308072703477_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/normal__201108011114.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/normal__201108011114.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__122_1306325762831_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201108222224.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201108222224.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_117_1306262456650_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_117_1306262456650_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_141_1306520154450_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_141_1306520154450_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/normal__201103140132.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/normal__201103140132.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201103200218.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__143_1306763822290_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__143_1306763822290_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/normal__201103221214.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/normal__201103221214.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__232_1308748524018_B1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__232_1308748524018_B1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__232_1308748524018_D1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__232_1308748524018_D1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__214_1308245489717_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__214_1308245489717_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal
wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__220_1308250132896_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__220_1308250132896_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101161027.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101161027.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__183_1308072703477_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__183_1308072703477_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__134_1306428161797_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__134_1306428161797_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201101180902.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201101180902.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_136_1306429977501_D1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__184_1308073010307_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_243_1309197760898_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__163_1307104470471_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__163_1307104470471_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_150_1306776340746_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_150_1306776340746_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__194_1308139824187_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__194_1308139824187_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270459.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101161027.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101161027.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201102052338.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201102052338.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/normal__201104141251.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/normal__201104141251.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__202_1308145175747_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__202_1308145175747_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_135_1306428972976_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_135_1306428972976_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201108222221.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201108222221.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__237_1308750231222_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__237_1308750231222_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__298_1311685888900_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__298_1311685888900_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__185_1308073325396_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__148_1306768801551_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__148_1306768801551_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_285_1311169246969_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_285_1311169246969_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__207_1308159792607_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101241433.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101241433.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__193_1308078104592_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__193_1308078104592_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__200_1308144251434_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__200_1308144251434_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__210_1308162935880_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__210_1308162935880_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__134_1306428161797_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__134_1306428161797_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__171_1307971016233_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__171_1307971016233_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201103291548.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201103291548.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_171_1307971016233_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_171_1307971016233_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__202_1308145175747_C1.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__202_1308145175747_C1.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201101051108.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201101051108.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__173_1307973611151_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__173_1307973611151_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104140118.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__153_1306848820671_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__153_1306848820671_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__223_1308337062581_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__223_1308337062581_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_156_1306936373241_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_156_1306936373241_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201102241217.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_240_1309201366049_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_258_1309352253234_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__154_1306935608852_D2.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__154_1306935608852_D2.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_271_1309369876160_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_271_1309369876160_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270458.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201104270458.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__220_1308250132896_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__220_1308250132896_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__240_1309201366049_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/murmur__240_1309201366049_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__216_1308245839516_C.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__216_1308245839516_C.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__145_1307987561278_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__145_1307987561278_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__140_1306519735121_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__140_1306519735121_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_198_1308141739338_D.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_198_1308141739338_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101091153.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101091153.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/extrastole__274_1311075637574_A.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/extrastole__274_1311075637574_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__230_1308595300880_B.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__230_1308595300880_B.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__178_1307989887769_D.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/murmur__160_1307100683334_A.wav
# load file  /kaggle/input/heartbeat-sounds/set_b/normal__148_1306768801551_D2.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_b/normal__148_1306768801551_D2.wav
# load file  /kaggle/input/heartbeat-sounds/set_a/murmur__201108222223.wav
# fixing audio length : /kaggle/input/heartbeat-sounds/set_a/murmur__201108222223.wav

# %%
np.unique(Yb,return_counts=True)
# Out:
# (array(['extrahls', 'extrastole', 'murmur', 'normal'], dtype=object),
#  array([129, 129, 129, 129]))

# %%
np.array(x_trainb_pad).shape,np.array(X_valb_pad).shape,np.array(X_testb_pad).shape
# Out:
# ((360, 40, 1), (78, 40, 1), (78, 40, 1))

# %%
# labels
# Classes [murmur,normal,ehtrahs,extrasoles]


def encode(y):
    labels = {
        'murmur'     : np.array([1,0,0,0]),
        'normal'     : np.array([0,1,0,0]),
        'extrahls'   : np.array([0,0,1,0]),
        'extrastole' : np.array([0,0,0,1]),
    }
    y_new = np.zeros(y.shape + (4,))
    for i,label in enumerate(y):
        y_new[i] = labels[label]
    return y_new

# %%
y_trainb_encoded = encode(y_trainb)
y_valb_encoded = encode(y_valb)
y_testb_encoded = encode(y_testb)

# %%
np.array(y_trainb_encoded).shape,np.array(y_valb_encoded).shape,np.array(y_testb_encoded).shape
# Out:
# ((360, 4), (78, 4), (78, 4))

# %% [markdown]
# ## Model

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers as tfl

# %%
from tensorflow.keras import optimizers

optimizer = optimizers.Adam(learning_rate=0.001)
loss_function = 'categorical_crossentropy'

# %%
checkpoint_filepath = '/kaggle/working/checkpoints/'

# %%
values = np.arange(0.000001,0.0003,0.00002)[::-1]
# values = np.array([0.00003,0.00005,0.00007,0.00009,0.0001,0.0003])[::-1]
boundaries = np.arange(10, 600,35)[:values.shape[0]-1]


scheduler = keras.optimizers.schedules.PiecewiseConstantDecay(
    list(boundaries), list(values))

lrscheduler = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=1)

# %%
model = keras.models.Sequential([
    tfl.Flatten(input_shape=(np.array(x_trainb_pad).shape[1],1,)),
    tfl.Dense(2048,activation='relu'),
    tfl.Dense(512,activation='relu'),

    tfl.Dense(4,activation='softmax')
],name='ClassifierA')
optimizer = keras.optimizers.Adam()
loss = keras.losses.CategoricalCrossentropy()
model.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
model.summary()
# Out:
# Model: "ClassifierA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_13 (Flatten)         (None, 40)                0
# _________________________________________________________________
# dense_39 (Dense)             (None,
LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2935 - accuracy: 0.8833 - val_loss: 0.5313 - val_accuracy: 0.8077
# Epoch 162/500
#
# Epoch 00162: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3830 - accuracy: 0.8361 - val_loss: 0.6945 - val_accuracy: 0.8077
# Epoch 163/500
#
# Epoch 00163: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3094 - accuracy: 0.8750 - val_loss: 0.5314 - val_accuracy: 0.8205
# Epoch 164/500
#
# Epoch 00164: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2998 - accuracy: 0.8944 - val_loss: 0.5851 - val_accuracy: 0.7436
# Epoch 165/500
#
# Epoch 00165: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2751 - accuracy: 0.8722 - val_loss: 0.6367 - val_accuracy: 0.8077
# Epoch 166/500
#
# Epoch 00166: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3395 - accuracy: 0.8778 - val_loss: 0.6743 - val_accuracy: 0.7949
# Epoch 167/500
#
# Epoch 00167: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3411 - accuracy: 0.8694 - val_loss: 0.6363 - val_accuracy: 0.8333
# Epoch 168/500
#
# Epoch 00168: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2498 - accuracy: 0.9111 - val_loss: 0.6118 - val_accuracy: 0.7564
# Epoch 169/500
#
# Epoch 00169: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2575 - accuracy: 0.9000 - val_loss: 0.8194 - val_accuracy: 0.7564
# Epoch 170/500
#
# Epoch 00170: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4107 - accuracy: 0.8306 - val_loss: 0.5721 - val_accuracy: 0.7949
# Epoch 171/500
#
# Epoch 00171: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2750 - accuracy: 0.8750 - val_loss: 0.8543 - val_accuracy: 0.7564
# Epoch 172/500
#
# Epoch 00172: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3178 - accuracy: 0.8500 - val_loss: 0.8072 - val_accuracy: 0.7949
# Epoch 173/500
#
# Epoch 00173: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3040 - accuracy: 0.8806 - val_loss: 0.5085 - val_accuracy: 0.8077
# Epoch 174/500
#
# Epoch 00174: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3442 - accuracy: 0.8722 - val_loss: 1.0080 - val_accuracy: 0.6667
# Epoch 175/500
#
# Epoch 00175: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4343 - accuracy: 0.8000 - val_loss: 0.8357 - val_accuracy: 0.8077
# Epoch 176/500
#
# Epoch 00176: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6087 - accuracy: 0.7944 - val_loss: 0.6747 - val_accuracy: 0.8077
# Epoch 177/500
#
# Epoch 00177: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7063 - accuracy: 0.7833 - val_loss: 0.7641 - val_accuracy: 0.8205
# Epoch 178/500
#
# Epoch 00178: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3654 - accuracy: 0.8417 - val_loss: 0.6360 - val_accuracy: 0.8077
# Epoch 179/500
#
# Epoch 00179: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3201 - accuracy: 0.8722 - val_loss: 0.6497 - val_accuracy: 0.7564
# Epoch 180/500
#
# Epoch 00180: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6024 - accuracy: 0.7639 - val_loss: 0.9799 - val_accuracy: 0.7692
# Epoch 181/500
#
# Epoch 00181: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4724 - accuracy: 0.8194 - val_loss: 0.5315 - val_accuracy: 0.8333

# %%
model.load_weights(checkpoint_filepath)

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
# Out:
# Text(0.5, 0, 'Epochs ')

# %%
checkpoint_filepath = '/kaggle/working/checkpoints/'

model.load_weights(checkpoint_filepath)
model.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6616 - accuracy: 0.8718
# [0.6616303324699402, 0.8717948794364929]

# %% [markdown]
# ## Adding regularization

# %%
input_shape = np.array(x_trainb_pad).shape[1:]

# %%
model_reg = keras.models.Sequential([
    tfl.Flatten(input_shape=input_shape),
    tfl.Dense(2048,activation='relu'),
    tfl.Dense(512,activation='relu'),
    tfl.Dropout(0.2),
    tfl.Dense(4,activation='softmax')
],name='ClassifierA')

model_reg.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
model_reg.summary()
# Out:
# Model: "ClassifierA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_14 (Flatten)         (None, 40)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 2048)              83968
# _________________________________________________________________
# dense_43 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 1,135,108
# Trainable params: 1,135,108
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_filepath = '/kaggle/working/checkpoints/model_reg/'
checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history=model_reg.fit(
    x=np.array(x_trainb_pad),
    y=y_trainb_encoded,epochs=500,
    validation_data=(np.array(X_valb_pad),y_valb_encoded),
    callbacks=[lrscheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 26ms/step - loss: 34.4010 - accuracy: 0.3278 - val_loss: 4.2527 - val_accuracy: 0.5897
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 7.0752 - accuracy: 0.4833 - val_loss: 1.9142 - val_accuracy: 0.5769
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 3.7810 - accuracy: 0.5778 - val_loss: 4.0881 - val_accuracy: 0.5128
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 3.2311 - accuracy: 0.5000 - val_loss: 2.4148 - val_accuracy: 0.4744
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 2.1857 - accuracy: 0.5306 - val_loss: 1.4292 - val_accuracy: 0.5641
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 1.4129 - accuracy: 0.5722 - val_loss: 1.6686 - val_accuracy: 0.4744
# Epoch 7/500
#
# Epoch 00007: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2936 - accuracy: 0.5611 - val_loss: 1.2779 - val_accuracy: 0.4231
# Epoch 8/500
#
# Epoch 00008: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0591 - accuracy: 0.5167 - val_loss: 0.9496 - val_accuracy: 0.6667
# Epoch 9/500
#
# Epoch 00009: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8654 - accuracy: 0.6083 - val_loss: 0.8016 - val_accuracy: 0.5641
# Epoch 10/500
#
# Epoch 00010: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.8328 - accuracy: 0.5806 - val_loss: 0.7301 - val_accuracy: 0.6923
# Epoch 11/500
#
# Epoch 00011: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.8513 - accuracy: 0.6333 - val_loss: 0.8504 - val_accuracy: 0.6026
# Epoch 12/500
#
# Epoch 00012: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7815 - accuracy: 0.6194 - val_loss: 0.7328 - val_accuracy: 0.6923
# Epoch 13/500
#
# Epoch 00013: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7728 - accuracy: 0.6389 - val_loss: 0.7943 - val_accuracy: 0.6667
# Epoch 14/500
#
# Epoch 00014: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7808 - accuracy: 0.6167 - val_loss: 0.8102 - val_accuracy: 0.6923
# Epoch 15/500
#
# Epoch 00015: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.8051 - accuracy: 0.6222 - val_loss: 0.7362 - val_accuracy: 0.6795
# Epoch 16/500
#
# Epoch 00016: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7680 - accuracy: 0.6250 - val_loss: 0.7602 - val_accuracy: 0.6923
# Epoch 17/500
#
# Epoch 00017: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7432 - accuracy: 0.6333 - val_loss: 0.7052 - val_accuracy: 0.7051
# Epoch 18/500
#
# Epoch 00018: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7637 - accuracy: 0.6389 - val_loss: 0.7737 - val_accuracy: 0.7051
# Epoch 19/500
#
# Epoch 00019: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7525 - accuracy: 0.6444 - val_loss: 0.7542 - val_accuracy: 0.6795
# Epoch 20/500
#
# Epoch 00020: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7678 - accuracy: 0.6333 - val_loss: 0.7344 - val_accuracy: 0.6667
# Epoch 21/500
#
# Epoch 00021: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.8141 - accuracy: 0.6194 - val_loss: 0.7525 - val_accuracy: 0.6667
# Epoch 22/500
#
# Epoch 00022: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7402 - accuracy: 0.6417 - val_loss: 0.7497 - val_accuracy: 0.6667
# Epoch 23/500
#
# Epoch 00023: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7533 - accuracy: 0.6194 - val_loss: 0.7416 - val_accuracy: 0.7564
# Epoch 24/500
#
# Epoch 00024: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7756 - accuracy: 0.6250 - val_loss: 0.7448 - val_accuracy: 0.7308
# Epoch 25/500
#
# Epoch 00025: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7244 - accuracy: 0.6722 - val_loss: 0.7135 - val_accuracy: 0.6923
# Epoch 26/500
#
# Epoch 00026: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7361 - accuracy: 0.6472 - val_loss: 0.7418 - val_accuracy: 0.7051
# Epoch 27/500
#
# Epoch 00027: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.7591 - accuracy: 0.6167 - val_loss: 0.7247 - val_accuracy: 0.7308
# Epoch 28/500
#
# Epoch 00028: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7534 - accuracy: 0.6444 - val_loss: 0.7214 - val_accuracy: 0.7051
# Epoch 29/500
#
# Epoch 00029: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7537 - accuracy: 0.6444 - val_loss: 0.7268 - val_accuracy: 0.7051
# Epoch 30/500
#
# Epoch 00030: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7333 - accuracy: 0.6611 - val_loss: 0.7218 - val_accuracy: 0.7179
# Epoch 31/500
#
# Epoch 00031: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.
LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5110 - accuracy: 0.7833 - val_loss: 0.7351 - val_accuracy: 0.6923
# Epoch 184/500
#
# Epoch 00184: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5316 - accuracy: 0.7639 - val_loss: 0.5866 - val_accuracy: 0.8077
# Epoch 185/500
#
# Epoch 00185: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5217 - accuracy: 0.7750 - val_loss: 0.6197 - val_accuracy: 0.7949
# Epoch 186/500
#
# Epoch 00186: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4986 - accuracy: 0.7806 - val_loss: 0.5626 - val_accuracy: 0.8205
# Epoch 187/500
#
# Epoch 00187: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.5135 - accuracy: 0.7667 - val_loss: 0.5838 - val_accuracy: 0.7949
# Epoch 188/500
#
# ...
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4692 - accuracy: 0.7944 - val_loss: 0.5649 - val_accuracy: 0.8718
# Epoch 230/500
#
# Epoch 00230: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4726 - accuracy: 0.8028 - val_loss: 0.6121 - val_accuracy: 0.7949
# Epoch 231/500
#
# Epoch 00231: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4248 - accuracy: 0.8250 - val_loss: 0.5722 - val_accuracy: 0.8462
# Epoch 232/500
#
# Epoch 00232: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4552 - accuracy: 0.8139 - val_loss: 0.6098 - val_accuracy: 0.8205
# Epoch 233/500
#
# Epoch 00233: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4502 - accuracy: 0.8083 - val_loss: 0.6179 - val_accuracy: 0.7949
# Epoch 234/500
#
# Epoch 00234: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4362 - accuracy: 0.7917 - val_loss: 0.6027 - val_accuracy: 0.8462
# Epoch 235/500
#
# Epoch 00235: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4476 - accuracy: 0.8167 - val_loss: 0.5965 - val_accuracy: 0.8333
# Epoch 236/500
#
# Epoch 00236: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4509 - accuracy: 0.7944 - val_loss: 0.6090 - val_accuracy: 0.8077
# Epoch 237/500
#
# Epoch 00237: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4854 - accuracy: 0.7833 - val_loss: 0.5900 - val_accuracy: 0.8205
# Epoch 238/500
#
# Epoch 00238: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4788 - accuracy: 0.7833 - val_loss: 0.6264 - val_accuracy: 0.7821
# Epoch 239/500
#
# Epoch 00239: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4360 - accuracy: 0.8278 - val_loss: 0.5828 - val_accuracy: 0.8333
# Epoch 240/500
#
# Epoch 00240: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4500 - accuracy: 0.8139 - val_loss: 0.5203 - val_accuracy: 0.8462
# Epoch 241/500
#
# Epoch 00241: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4412 - accuracy: 0.7889 - val_loss: 0.5784 - val_accuracy: 0.8590
# Epoch 242/500
#
# Epoch 00242: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4344 - accuracy: 0.8139 - val_loss: 0.5538 - val_accuracy: 0.8462
# Epoch 243/500
#
# Epoch 00243: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4279 - accuracy: 0.8139 - val_loss: 0.6382 - val_accuracy: 0.8077
# Epoch 244/500
#
# Epoch 00244: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4478 - accuracy: 0.7917 - val_loss: 0.5865 - val_accuracy: 0.8077
# Epoch 245/500
#
# Epoch 00245: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4362 - accuracy: 0.8111 - val_loss: 0.5403 - val_accuracy: 0.8590
# Epoch 246/500
#
# Epoch 00246: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4227 - accuracy: 0.8111 - val_loss: 0.6323 - val_accuracy: 0.8205
# Epoch 247/500
#
# Epoch 00247: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4334 - accuracy: 0.8194 - val_loss: 0.5675 - val_accuracy: 0.8205
# Epoch 248/500
#
# Epoch 00248: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4331 - accuracy: 0.8111 - val_loss: 0.6474 - val_accuracy: 0.7949
# Epoch 249/500
#
# Epoch 00249: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4278 - accuracy: 0.8222 - val_loss: 0.6466 - val_accuracy: 0.7821
# Epoch 250/500
#
# Epoch 00250: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4907 - accuracy: 0.7750 - val_loss: 0.6155 - val_accuracy: 0.7821
# Epoch 251/500
#
# Epoch 00251: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4960 - accuracy: 0.7667 - val_loss: 0.6564 - val_accuracy: 0.8077
# Epoch 252/500
#
# Epoch 00252: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4935 - accuracy: 0.7806 - val_loss: 0.6818 - val_accuracy: 0.7308
# Epoch 253/500
#
# Epoch 00253: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4641 - accuracy: 0.8028 - val_loss: 0.5704 - val_accuracy: 0.8077
# Epoch 254/500
#
# Epoch 00254: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4408 - accuracy: 0.8000 - val_loss: 0.6098 - val_accuracy: 0.8333
# Epoch 255/500
#
# Epoch 00255: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4368 - accuracy: 0.8194 - val_loss: 0.5874 - val_accuracy: 0.8077
# Epoch 256/500
#
# Epoch 00256: LearningRateScheduler setting learning rate to tf.Tensor(0.000141, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4419 - accuracy: 0.8111 - val_loss: 0.6082 - val_accuracy: 0.8077
# Epoch 257/500
#
# Epoch 00257: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4380 - accuracy: 0.8111 - val_loss: 0.6144 - val_accuracy: 0.8333
# Epoch 258/500
#
# Epoch 00258: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4180 - accuracy: 0.8222 - val_loss: 0.6030 - val_accuracy: 0.8077
# Epoch 259/500
#
# Epoch 00259: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4411 - accuracy: 0.8139 - val_loss: 0.6432 - val_accuracy: 0.8333
# Epoch 260/500
#
# Epoch 00260: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4403 - accuracy: 0.8000 - val_loss: 0.5777 - val_accuracy: 0.8590
# Epoch 261/500
#
# Epoch 00261: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4060 - accuracy: 0.8306 - val_loss: 0.6403 - val_accuracy: 0.7949
# Epoch 262/500
#
# Epoch 00262: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4202 - accuracy: 0.8278 - val_loss: 0.5851 - val_accuracy: 0.8205
# Epoch 263/500
#
# Epoch 00263: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4178 - accuracy: 0.8250 - val_loss: 0.6252 - val_accuracy: 0.8077
# Epoch 264/500
#
# Epoch 00264: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4053 - accuracy: 0.8139 - val_loss: 0.6275 - val_accuracy: 0.7821
# Epoch 265/500
#
# Epoch 00265: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3871 - accuracy: 0.8250 - val_loss: 0.6470 - val_accuracy: 0.7821
# Epoch 266/500
#
# Epoch 00266: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4178 - accuracy: 0.8083 - val_loss: 0.5948 - val_accuracy: 0.8333
# Epoch 267/500
#
# Epoch 00267: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4151 - accuracy: 0.7972 - val_loss: 0.6092 - val_accuracy: 0.8077
# Epoch 268/500
#
# Epoch 00268: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3978 - accuracy: 0.8250 - val_loss: 0.5953 - val_accuracy: 0.8205
# Epoch 269/500
#
# Epoch 00269: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4145 - accuracy: 0.7944 - val_loss: 0.6499 - val_accuracy: 0.7692
# Epoch 270/500
#
# Epoch 00270: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4206 - accuracy: 0.8167 - val_loss: 0.5676 - val_accuracy: 0.8205
# Epoch 271/500
#
# Epoch 00271: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4321 - accuracy: 0.8139 - val_loss: 0.6247 - val_accuracy: 0.7949
# Epoch 272/500
#
# Epoch 00272: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4166 - accuracy: 0.8083 - val_loss: 0.6821 - val_accuracy: 0.7564
# Epoch 273/500
#
# Epoch 00273: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4280 - accuracy: 0.8083 - val_loss: 0.5810 - val_accuracy: 0.8077
# Epoch 274/500
#
# Epoch 00274: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4187 - accuracy: 0.8278 - val_loss: 0.6085 - val_accuracy: 0.7949
# Epoch 275/500
#
# Epoch 00275: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4074 - accuracy: 0.8056 - val_loss: 0.6058 - val_accuracy: 0.7821
# Epoch 276/500
#
# Epoch 00276: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3949 - accuracy: 0.8444 - val_loss: 0.6041 - val_accuracy: 0.8333
# Epoch 277/500
#
# Epoch 00277: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3961 - accuracy: 0.8389 - val_loss: 0.5821 - val_accuracy: 0.8205
# Epoch 278/500
#
# Epoch 00278: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3888 - accuracy: 0.8333 - val_loss: 0.6382 - val_accuracy: 0.8077
# Epoch 279/500
#
# Epoch 00279: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3896 - accuracy: 0.8250 - val_loss: 0.5814 - val_accuracy: 0.8333
# Epoch 280/500
#
# Epoch 00280: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4155 - accuracy: 0.8111 - val_loss: 0.6079 - val_accuracy: 0.7949
# Epoch 281/500
#
# Epoch 00281: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4065 - accuracy: 0.8139 - val_loss: 0.6698 - val_accuracy: 0.7821
# Epoch 282/500
#
# Epoch 00282: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4393 - accuracy: 0.8111 - val_loss: 0.6003 - val_accuracy: 0.8077
# Epoch 283/500
#
# Epoch 00283: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4168 - accuracy: 0.8278 - val_loss: 0.5725 - val_accuracy: 0.8333
# Epoch 284/500
#
# Epoch 00284: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3884 - accuracy: 0.8306 - val_loss: 0.6792 - val_accuracy: 0.7821
# Epoch 285/500
#
# Epoch 00285: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4033 - accuracy: 0.7861 - val_loss: 0.5529 - val_accuracy: 0.8333
# Epoch 286/500
#
# Epoch 00286: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3871 - accuracy: 0.8306 - val_loss: 0.5684 - val_accuracy: 0.8462
# Epoch 287/500
#
# Epoch 00287: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3906 - accuracy: 0.8389 - val_loss: 0.6781 - val_accuracy: 0.7949
# Epoch 288/500
#
# Epoch 00288: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3810 - accuracy: 0.8472 - val_loss: 0.5291 - val_accuracy: 0.8590
# Epoch 289/500
#
# Epoch 00289: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4000 - accuracy: 0.8278 - val_loss: 0.5899 - val_accuracy: 0.8462
# Epoch 290/500
#
# Epoch 00290: LearningRateScheduler setting learning rate to tf.Tensor(0.00012100000000000001, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3718 - accuracy: 0.8417 - val_loss: 0.5999 - val_accuracy: 0.7949

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
# Out:
# Text(0.5, 0, 'Epochs ')

# %%
model_reg.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5999 - accuracy: 0.7949
# [0.5998568534851074, 0.7948718070983887]

# %% [markdown]
# Model with regularization is much better (loss lower) so we discard the first result.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Accuracy

# %%
checkpoint_filepath = '/kaggle/working/checkpoints/'

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(np.array(X_testb_pad),y_testb_encoded)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1177 - accuracy: 0.6410
# [1.1177014112472534, 0.6410256624221802]

# %%
y_pred = model.predict(np.array(X_testb_pad))
y_pred_max = np.argsort(y_pred,axis=-1)[:,::-1][:,0]
y_true_max = np.argsort(y_testb_encoded,axis=-1)[:,::-1][:,0]

# %% [markdown]
# ## F1 score

# %%
from sklearn.metrics import f1_score, classification_report

print(f1_score(y_true_max, y_pred_max, average='micro'))
target_names = [
    'murmur'    ,
    'normal'    ,
    'extrahls'  ,
    'extrastole',
]
print(classification_report(y_true_max, y_pred_max, target_names=target_names))
# Out:
# 0.6410256410256411
#               precision    recall  f1-score   support
#
#       murmur       0.91      0.42      0.57        24
#       normal       0.46      0.55      0.50        20
#     extrahls       0.84      1.00      0.91        16
#   extrastole       0.54      0.72      0.62        18
#
#     accuracy                           0.64        78
#    macro avg       0.69      0.67      0.65        78
# weighted avg       0.69      0.64      0.63        78

# %% [markdown]
# ## AUC

# %%
m = tf.keras.metrics.AUC(num_thresholds=80)
m.update_state(y_testb_encoded, y_pred)

m.result().numpy()
# Out:
# 0.88173896

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn as sns

conf = tf.math.confusion_matrix(y_pred_max,y_true_max)

sns.heatmap(conf,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model : CNN

# %%
model_cnn = keras.models.Sequential([
#     tfl.Flatten(input_shape=(40,1)),
    tfl.Conv1D(64,3,activation='relu',padding='same',input_shape=(40,1)),
    tfl.Conv1D(64,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.Flatten(),
    tfl.Dense(64,activation='relu'),
    tfl.Dense(4,activation='softmax'),

])

model_cnn.compile(optimizer=optimizer,loss=loss_function,metrics=['accuracy'])
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 40, 64)            256
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 40, 64)            12352
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 20, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 20, 32)            6176
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 20, 32)            3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 32)            0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 320)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                20544
# _________________________________________________________________
# dense_46 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 42,692
# Trainable params: 42,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_filepath_cnn = '/kaggle/working/checkpoints/cnn'
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 50, mode='min')

checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath_cnn,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history=model_cnn.fit(
    x=np.array(x_trainb_pad),
    y=y_trainb_encoded,epochs=500,
    validation_data=(np.array(X_valb_pad),y_valb_encoded),
    callbacks=[lrscheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 36ms/step - loss: 1.5633 - accuracy: 0.4028 - val_loss: 1.3403 - val_accuracy: 0.5128
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2060 - accuracy: 0.4778 - val_loss: 0.9331 - val_accuracy: 0.5256
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9421 - accuracy: 0.5528 - val_loss: 0.7821 - val_accuracy: 0.6538
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8157 - accuracy: 0.6028 - val_loss: 0.7714 - val_accuracy: 0.6538
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7950 - accuracy: 0.6167 - val_loss: 0.9311 - val_accuracy: 0.5641
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8724 - accuracy: 0.5778 - val_loss: 0.7567 - val_accuracy: 0.6795
# Epoch 7/500
#
# Epoch 00007: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8659 - accuracy: 0.5333 - val_loss: 0.7141 - val_accuracy: 0.6923
# Epoch 8/500
#
# Epoch 00008: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8142 - accuracy: 0.6333 - val_loss: 0.7737 - val_accuracy: 0.6154
# Epoch 9/500
#
# Epoch 00009: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8048 - accuracy: 0.6028 - val_loss: 0.8694 - val_accuracy: 0.6154
# Epoch 10/500
#
# Epoch 00010: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8005 - accuracy: 0.6333 - val_loss: 0.8472 - val_accuracy: 0.5769
# Epoch 11/500
#
# Epoch 00011: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7836 - accuracy: 0.5889 - val_loss: 0.7900 - val_accuracy: 0.5897
# Epoch 12/500
#
# Epoch 00012: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8127 - accuracy: 0.5861 - val_loss: 0.7200 - val_accuracy: 0.6795
# Epoch 13/500
#
# Epoch 00013: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7260 - accuracy: 0.6444 - val_loss: 0.7693 - val_accuracy: 0.6282
# Epoch 14/500
#
# Epoch 00014: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7427 - accuracy: 0.6639 - val_loss: 0.7800 - val_accuracy: 0.6667
# Epoch 15/500
#
# Epoch 00015: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7166 - accuracy: 0.6583 - val_loss: 0.7137 - val_accuracy: 0.7051
# Epoch 16/500
#
# Epoch 00016: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6867 - accuracy: 0.6750 - val_loss: 0.7294 - val_accuracy: 0.6410
# Epoch 17/500
#
# Epoch 00017: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.6944 - accuracy: 0.6667 - val_loss: 0.7600 - val_accuracy: 0.7436
# Epoch 18/500
#
# Epoch 00018: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.
LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1465 - accuracy: 0.9667 - val_loss: 0.5554 - val_accuracy: 0.8333
# Epoch 127/500
#
# Epoch 00127: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1246 - accuracy: 0.9694 - val_loss: 0.5540 - val_accuracy: 0.8462
# Epoch 128/500
#
# Epoch 00128: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1153 - accuracy: 0.9750 - val_loss: 0.5459 - val_accuracy: 0.8590
# Epoch 129/500
#
# Epoch 00129: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1135 - accuracy: 0.9722 - val_loss: 0.5627 - val_accuracy: 0.8462
# Epoch 130/500
#
# Epoch 00130: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1197 - accuracy: 0.9722 - val_loss: 0.5997 - val_accuracy: 0.8205
# Epoch 131/500
#
# Epoch 00131: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1157 - accuracy: 0.9778 - val_loss: 0.5086 - val_accuracy: 0.8462
# Epoch 132/500
#
# Epoch 00132: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1373 - accuracy: 0.9667 - val_loss: 0.5488 - val_accuracy: 0.8462
# Epoch 133/500
#
# Epoch 00133: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1181 - accuracy: 0.9667 - val_loss: 0.6376 - val_accuracy: 0.8462
# Epoch 134/500
#
# Epoch 00134: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1129 - accuracy: 0.9778 - val_loss: 0.5429 - val_accuracy: 0.8333
# Epoch 135/500
#
# Epoch 00135: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1116 - accuracy: 0.9833 - val_loss: 0.5075 - val_accuracy: 0.8590
# Epoch 136/500
#
# Epoch 00136: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1025 - accuracy: 0.9778 - val_loss: 0.5902 - val_accuracy: 0.8462
# Epoch 137/500
#
# Epoch 00137: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1022 - accuracy: 0.9778 - val_loss: 0.5674 - val_accuracy: 0.8462
# Epoch 138/500
#
# Epoch 00138: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1004 - accuracy: 0.9750 - val_loss: 0.5836 - val_accuracy: 0.8462

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
# Out:
# Text(0.5, 0, 'Epochs ')

# %%
model_cnn.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 27ms/step - loss: 0.5836 - accuracy: 0.8462
# [0.5836395621299744, 0.8461538553237915]

# %% [markdown]
# We add batch normalization and dropout.

# %%
model_cnn_reg = keras.models.Sequential([
    tfl.Conv1D(64,3,activation='relu',padding='same',input_shape=input_shape),
    tfl.Conv1D(64,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.BatchNormalization(),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.BatchNormalization(),
    tfl.Flatten(),
    tfl.Dropout(0.2),
    tfl.Dense(64,activation='relu'),
    tfl.Dropout(0.2),
    tfl.Dense(4,activation='softmax'),

])

model_cnn_reg.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
model_cnn_reg.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 40, 64)            256
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 40, 64)            12352
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 20, 64)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20, 64)            256
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 20, 32)            6176
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 20, 32)            3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 10, 32)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 32)            128
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 320)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 320)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 64)                20544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 43,076
# Trainable params: 42,884
# Non-trainable params: 192
# _________________________________________________________________

# %%
checkpoint_filepath_cnn = '/kaggle/working/checkpoints/cnn_reg'
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 50, mode='min')

checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history=model_cnn_reg.fit(
    x=np.array(x_trainb_pad),
    y=y_trainb_encoded,epochs=500,
    validation_data=(np.array(X_valb_pad),y_valb_encoded),
    callbacks=[lrscheduler,checkpoint]
)
# Out:
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 2s 42ms/step - loss: 1.3125 - accuracy: 0.4333 - val_loss: 1.3651 - val_accuracy: 0.4103
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0114 - accuracy: 0.5500 - val_loss: 1.0988 - val_accuracy: 0.4359
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.9121 - accuracy: 0.5944 - val_loss: 0.9949 - val_accuracy: 0.5128
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8731 - accuracy: 0.5750 - val_loss: 0.9672 - val_accuracy: 0.4615
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.8313 - accuracy: 0.6250 - val_loss: 1.0106 - val_accuracy: 0.4615
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.
LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0806 - accuracy: 0.9694 - val_loss: 0.6224 - val_accuracy: 0.8333
# Epoch 143/500
#
# Epoch 00143: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0881 - accuracy: 0.9750 - val_loss: 0.6884 - val_accuracy: 0.7949
# Epoch 144/500
#
# Epoch 00144: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0968 - accuracy: 0.9750 - val_loss: 0.6520 - val_accuracy: 0.7821
# Epoch 145/500
#
# Epoch 00145: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0824 - accuracy: 0.9750 - val_loss: 0.6120 - val_accuracy: 0.8077
# Epoch 146/500
#
# Epoch 00146: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0926 - accuracy: 0.9722 - val_loss: 0.6092 - val_accuracy: 0.8205
# Epoch 147/500
#
# Epoch 00147: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0764 - accuracy: 0.9778 - val_loss: 0.6294 - val_accuracy: 0.8077
# Epoch 148/500
#
# Epoch 00148: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0879 - accuracy: 0.9750 - val_loss: 0.5878 - val_accuracy: 0.8205
# Epoch 149/500
#
# Epoch 00149: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0666 - accuracy: 0.9806 - val_loss: 0.5774 - val_accuracy: 0.7949
# Epoch 150/500
#
# Epoch 00150: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1020 - accuracy: 0.9694 - val_loss: 0.6302 - val_accuracy: 0.8077
# Epoch 151/500
#
# Epoch 00151: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0590 - accuracy: 0.9861 - val_loss: 0.7137 - val_accuracy: 0.8077
# Epoch 152/500
#
# Epoch 00152: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0877 - accuracy: 0.9778 - val_loss: 0.7028 - val_accuracy: 0.8333
# Epoch 153/500
#
# Epoch 00153: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0684 - accuracy: 0.9806 - val_loss: 0.6561 - val_accuracy: 0.8205
# Epoch 154/500
#
# Epoch 00154: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.5926 - val_accuracy: 0.8077
# Epoch 155/500
#
# Epoch 00155: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0760 - accuracy: 0.9722 - val_loss: 0.6319 - val_accuracy: 0.8205
# Epoch 156/500
#
# Epoch 00156: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0879 - accuracy: 0.9639 - val_loss: 0.6106 - val_accuracy: 0.8077
# Epoch 157/500
#
# Epoch 00157: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0878 - accuracy: 0.9694 - val_loss: 0.6210 - val_accuracy: 0.8077
# Epoch 158/500
#
# Epoch 00158: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0776 - accuracy: 0.9750 - val_loss: 0.6156 - val_accuracy: 0.8077
# Epoch 159/500
#
# Epoch 00159: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0716 - accuracy: 0.9833 - val_loss: 0.6429 - val_accuracy: 0.8333
# Epoch 160/500
#
# Epoch 00160: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0649 - accuracy: 0.9833 - val_loss: 0.6641 - val_accuracy: 0.8333
# Epoch 161/500
#
# Epoch 00161: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0669 - accuracy: 0.9806 - val_loss: 0.6758 - val_accuracy: 0.8205
# Epoch 162/500
#
# Epoch 00162: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0729 - accuracy: 0.9639 - val_loss: 0.6861 - val_accuracy: 0.8077
# Epoch 163/500
#
# Epoch 00163: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0631 - accuracy: 0.9833 - val_loss: 0.6487 - val_accuracy: 0.8205
# Epoch 164/500
#
# Epoch 00164: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0580 - accuracy: 0.9889 - val_loss: 0.6344 - val_accuracy: 0.8205
# Epoch 165/500
#
# Epoch 00165: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0654 - accuracy: 0.9917 - val_loss: 0.6231 - val_accuracy: 0.8205
# Epoch 166/500
#
# Epoch 00166: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 0.9917 - val_loss: 0.6336 - val_accuracy: 0.8333
# Epoch 167/500
#
# Epoch 00167: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0590 - accuracy: 0.9861 - val_loss: 0.6608 - val_accuracy: 0.8205
# Epoch 168/500
#
# Epoch 00168: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 0.9778 - val_loss: 0.6481 - val_accuracy: 0.7949
# Epoch 169/500
#
# Epoch 00169: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0875 - accuracy: 0.9750 - val_loss: 0.6638 - val_accuracy: 0.8077
# Epoch 170/500
#
# Epoch 00170: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0671 - accuracy: 0.9750 - val_loss: 0.6477 - val_accuracy: 0.8333
# Epoch 171/500
#
# Epoch 00171: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0838 - accuracy: 0.9667 - val_loss: 0.6944 - val_accuracy: 0.8205
# Epoch 172/500
#
# Epoch 00172: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0621 - accuracy: 0.9806 - val_loss: 0.6616 - val_accuracy: 0.8077
# Epoch 173/500
#
# Epoch 00173: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0653 - accuracy: 0.9861 - val_loss: 0.6638 - val_accuracy: 0.7949
# Epoch 174/500
#
# Epoch 00174: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0684 - accuracy: 0.9861 - val_loss: 0.6529 - val_accuracy: 0.7821
# Epoch 175/500
#
# Epoch 00175: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0619 - accuracy: 0.9861 - val_loss: 0.6635 - val_accuracy: 0.8077
# Epoch 176/500
#
# Epoch 00176: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0712 - accuracy: 0.9722 - val_loss: 0.6246 - val_accuracy: 0.8333
# Epoch 177/500
#
# Epoch 00177: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0852 - accuracy: 0.9694 - val_loss: 0.6321 - val_accuracy: 0.8333
# Epoch 178/500
#
# Epoch 00178: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0804 - accuracy: 0.9778 - val_loss: 0.6698 - val_accuracy: 0.8077
# Epoch 179/500
#
# Epoch 00179: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0788 - accuracy: 0.9861 - val_loss: 0.6140 - val_accuracy: 0.8205
# Epoch 180/500
#
# Epoch 00180: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0532 - accuracy: 0.9861 - val_loss: 0.6218 - val_accuracy: 0.8333
# Epoch 181/500
#
# Epoch 00181: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0791 - accuracy: 0.9750 - val_loss: 0.6270 - val_accuracy: 0.8205
# Epoch 182/500
#
# Epoch 00182: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0520 - accuracy: 0.9889 - val_loss: 0.6638 - val_accuracy: 0.7949
# Epoch 183/500
#
# Epoch 00183: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0484 - accuracy: 0.9889 - val_loss: 0.6939 - val_accuracy: 0.7949
# Epoch 184/500
#
# Epoch 00184: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0586 - accuracy: 0.9861 - val_loss: 0.7192 - val_accuracy: 0.8205
# Epoch 185/500
#
# Epoch 00185: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 0.6757 - val_accuracy: 0.8077
# Epoch 186/500
#
# Epoch 00186: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0520 - accuracy: 0.9833 - val_loss: 0.6892 - val_accuracy: 0.7949
# Epoch 187/500
#
# Epoch 00187: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9861 - val_loss: 0.5876 - val_accuracy: 0.8333
# Epoch 188/500
#
# ...
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0142 - accuracy: 0.9972 - val_loss: 0.7799 - val_accuracy: 0.8077
# Epoch 439/500
#
# Epoch 00439: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0193 - accuracy: 0.9972 - val_loss: 0.7852 - val_accuracy: 0.8077
# Epoch 440/500
#
# Epoch 00440: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0234 - accuracy: 0.9944 - val_loss: 0.7848 - val_accuracy: 0.8077
# Epoch 441/500
#
# Epoch 00441: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9972 - val_loss: 0.7840 - val_accuracy: 0.8077
# Epoch 442/500
#
# Epoch 00442: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0206 - accuracy: 0.9972 - val_loss: 0.7845 - val_accuracy: 0.8077
# Epoch 443/500
#
# Epoch 00443: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.7908 - val_accuracy: 0.8077
# Epoch 444/500
#
# Epoch 00444: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0152 - accuracy: 0.9972 - val_loss: 0.7891 - val_accuracy: 0.8077
# Epoch 445/500
#
# Epoch 00445: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.7860 - val_accuracy: 0.8077
# Epoch 446/500
#
# Epoch 00446: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.7865 - val_accuracy: 0.8077
# Epoch 447/500
#
# Epoch 00447: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0130 - accuracy: 0.9944 - val_loss: 0.7879 - val_accuracy: 0.8077
# Epoch 448/500
#
# Epoch 00448: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0198 - accuracy: 0.9944 - val_loss: 0.7906 - val_accuracy: 0.8077
# Epoch 449/500
#
# Epoch 00449: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0139 - accuracy: 0.9972 - val_loss: 0.7920 - val_accuracy: 0.8205
# Epoch 450/500
#
# Epoch 00450: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0213 - accuracy: 0.9944 - val_loss: 0.7908 - val_accuracy: 0.8205
# Epoch 451/500
#
# Epoch 00451: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0178 - accuracy: 0.9917 - val_loss: 0.7825 - val_accuracy: 0.8205
# Epoch 452/500
#
# Epoch 00452: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 0.7842 - val_accuracy: 0.8205
# Epoch 453/500
#
# Epoch 00453: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0145 - accuracy: 0.9972 - val_loss: 0.7849 - val_accuracy: 0.8205
# Epoch 454/500
#
# Epoch 00454: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0241 - accuracy: 0.9889 - val_loss: 0.7895 - val_accuracy: 0.8077
# Epoch 455/500
#
# Epoch 00455: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0208 - accuracy: 0.9944 - val_loss: 0.7830 - val_accuracy: 0.8077
# Epoch 456/500
#
# Epoch 00456: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0143 - accuracy: 0.9972 - val_loss: 0.7820 - val_accuracy: 0.8077
# Epoch 457/500
#
# Epoch 00457: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.7842 - val_accuracy: 0.8205
# Epoch 458/500
#
# Epoch 00458: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9972 - val_loss: 0.7823 - val_accuracy: 0.8205
# Epoch 459/500
#
# Epoch 00459: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0123 - accuracy: 0.9944 - val_loss: 0.7837 - val_accuracy: 0.8333
# Epoch 460/500
#
# Epoch 00460: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.7734 - val_accuracy: 0.8333
# Epoch 461/500
#
# Epoch 00461: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.7691 - val_accuracy: 0.8333
# Epoch 462/500
#
# Epoch 00462: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 0.7776 - val_accuracy: 0.8333
# Epoch 463/500
#
# Epoch 00463: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0225 - accuracy: 0.9944 - val_loss: 0.7783 - val_accuracy: 0.8333
# Epoch 464/500
#
# Epoch 00464: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0223 - accuracy: 0.9917 - val_loss: 0.7777 - val_accuracy: 0.8205
# Epoch 465/500
#
# Epoch 00465: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0142 - accuracy: 0.9972 - val_loss: 0.7769 - val_accuracy: 0.8205
# Epoch 466/500
#
# Epoch 00466: LearningRateScheduler setting learning rate to tf.Tensor(2.1000000000000002e-05, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.7797 - val_accuracy: 0.8205
# Epoch 467/500
#
# Epoch 00467: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9944 - val_loss: 0.7800 - val_accuracy: 0.8205
# Epoch 468/500
#
# Epoch 00468: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0136 - accuracy: 0.9972 - val_loss: 0.7801 - val_accuracy: 0.8205
# Epoch 469/500
#
# Epoch 00469: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.7793 - val_accuracy: 0.8205
# Epoch 470/500
#
# Epoch 00470: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.7789 - val_accuracy: 0.8205
# Epoch 471/500
#
# Epoch 00471: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.7785 - val_accuracy: 0.8205
# Epoch 472/500
#
# Epoch 00472: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 0.9972 - val_loss: 0.7777 - val_accuracy: 0.8205
# Epoch 473/500
#
# Epoch 00473: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0210 - accuracy: 0.9917 - val_loss: 0.7767 - val_accuracy: 0.8205
# Epoch 474/500
#
# Epoch 00474: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 0.7756 - val_accuracy: 0.8205
# Epoch 475/500
#
# Epoch 00475: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0122 - accuracy: 0.9972 - val_loss: 0.7758 - val_accuracy: 0.8205
# Epoch 476/500
#
# Epoch 00476: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.7760 - val_accuracy: 0.8205
# Epoch 477/500
#
# Epoch 00477: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9944 - val_loss: 0.7759 - val_accuracy: 0.8333
# Epoch 478/500
#
# Epoch 00478: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.7756 - val_accuracy: 0.8333
# Epoch 479/500
#
# Epoch 00479: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.7754 - val_accuracy: 0.8333
# Epoch 480/500
#
# Epoch 00480: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 0.7753 - val_accuracy: 0.8333
# Epoch 481/500
#
# Epoch 00481: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0226 - accuracy: 0.9889 - val_loss: 0.7759 - val_accuracy: 0.8333
# Epoch 482/500
#
# Epoch 00482: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0201 - accuracy: 0.9972 - val_loss: 0.7760 - val_accuracy: 0.8333
# Epoch 483/500
#
# Epoch 00483: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.7762 - val_accuracy: 0.8333
# Epoch 484/500
#
# Epoch 00484: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.7757 - val_accuracy: 0.8333
# Epoch 485/500
#
# Epoch 00485: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.7760 - val_accuracy: 0.8333
# Epoch 486/500
#
# Epoch 00486: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.7765 - val_accuracy: 0.8333
# Epoch 487/500
#
# Epoch 00487: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0187 - accuracy: 0.9972 - val_loss: 0.7771 - val_accuracy: 0.8333
# Epoch 488/500
#
# Epoch 00488: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0187 - accuracy: 0.9944 - val_loss: 0.7773 - val_accuracy: 0.8333
# Epoch 489/500
#
# Epoch 00489: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.7767 - val_accuracy: 0.8333
# Epoch 490/500
#
# Epoch 00490: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.7760 - val_accuracy: 0.8333
# Epoch 491/500
#
# Epoch 00491: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0177 - accuracy: 0.9972 - val_loss: 0.7755 - val_accuracy: 0.8333
# Epoch 492/500
#
# Epoch 00492: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0244 - accuracy: 0.9889 - val_loss: 0.7761 - val_accuracy: 0.8333
# Epoch 493/500
#
# Epoch 00493: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.7756 - val_accuracy: 0.8333
# Epoch 494/500
#
# Epoch 00494: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0228 - accuracy: 0.9972 - val_loss: 0.7757 - val_accuracy: 0.8333
# Epoch 495/500
#
# Epoch 00495: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.7758 - val_accuracy: 0.8333
# Epoch 496/500
#
# Epoch 00496: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0236 - accuracy: 0.9944 - val_loss: 0.7762 - val_accuracy: 0.8333
# Epoch 497/500
#
# Epoch 00497: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.7762 - val_accuracy: 0.8333
# Epoch 498/500
#
# Epoch 00498: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9972 - val_loss: 0.7770 - val_accuracy: 0.8333
# Epoch 499/500
#
# Epoch 00499: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.7765 - val_accuracy: 0.8333
# Epoch 500/500
#
# Epoch 00500: LearningRateScheduler setting learning rate to tf.Tensor(1e-06, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.7757 - val_accuracy: 0.8333

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
# Out:
# Text(0.5, 0, 'Epochs ')

# %%
model_cnn_reg.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7757 - accuracy: 0.8333
# [0.7756972908973694, 0.8333333134651184]

# %% [markdown]
# first model is better

# %%
model_cnn.load_weights('/kaggle/working/checkpoints/cnn')
model_cnn.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5518 - accuracy: 0.8590
# [0.5517873764038086, 0.8589743375778198]

# %% [markdown]
# # Evaluate

# %%
model_cnn.evaluate(np.array(X_testb_pad),y_testb_encoded)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6919 - accuracy: 0.6538
# [0.691851794719696, 0.6538461446762085]

# %%
y_pred = model_cnn.predict(np.array(X_testb_pad))
y_pred_max = np.argsort(y_pred,axis=-1)[:,::-1][:,0]
y_true_max = np.argsort(y_testb_encoded,axis=-1)[:,::-1][:,0]

# %%
from sklearn.metrics import f1_score, classification_report

f1_score(y_true_max, y_pred_max, average='micro')

print(classification_report(y_true_max, y_pred_max, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       murmur       0.70      0.67      0.68        24
#       normal       0.41      0.35      0.38        20
#     extrahls       0.89      1.00      0.94        16
#   extrastole       0.60      0.67      0.63        18
#
#     accuracy                           0.65        78
#    macro avg       0.65      0.67      0.66        78
# weighted avg       0.64      0.65      0.65        78

# %%
m = tf.keras.metrics.AUC(num_thresholds=80)
m.update_state(y_testb_encoded, y_pred)

m.result().numpy()
# Out:
# 0.9112152

# %%
import seaborn as sns

conf = tf.math.confusion_matrix(y_pred_max,y_true_max)

sns.heatmap(conf,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Going deeper with feed forward

# %%
model_deep = keras.models.Sequential([
    tfl.Flatten(input_shape=input_shape),
    tfl.Dense(2048,activation='relu'),
    tfl.Dense(1024,activation='relu'),
    tfl.Dense(64,activation='relu'),

    tfl.Dense(64,activation='relu'),


    tfl.Dense(4,activation='softmax')
],name='ClassifierA')
optimizer = keras.optimizers.Adam()
loss = keras.losses.CategoricalCrossentropy()
model_deep.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
model_deep.summary()
# Out:
# Model: "ClassifierA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_17 (Flatten)         (None, 40)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 2048)              83968
# _________________________________________________________________
# dense_50 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dense_51 (Dense)             (None, 64)                65600
# _________________________________________________________________
# dense_52 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_53 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 2,252,164
# Trainable params: 2,252,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 50, mode='min')
checkpoint = keras.callbacks.ModelCheckpoint(
    filepath='/kaggle/working/checkpoints/model_deep',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history=model_deep.fit(
    x=np.array(x_trainb_pad),
    y=y_trainb_encoded,epochs=500,
    validation_data=(np.array(X_valb_pad),y_valb_encoded),
    callbacks=[lrscheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 38ms/step - loss: 4.8981 - accuracy: 0.3250 - val_loss: 2.2410 - val_accuracy: 0.3590
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 1.6037 - accuracy: 0.4194 - val_loss: 1.3470 - val_accuracy: 0.5641
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 1.2104 - accuracy: 0.5444 - val_loss: 0.9378 - val_accuracy: 0.6410
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 1.0305 - accuracy: 0.5333 - val_loss: 0.9159 - val_accuracy: 0.6154
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.8866 - accuracy: 0.6194 - val_loss: 0.7920 - val_accuracy: 0.6795
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.8685 - accuracy: 0.6167 - val_loss: 0.8883 - val_accuracy: 0.6154
# Epoch 7/500
#
# Epoch 00007: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.9474 - accuracy: 0.5750 - val_loss: 0.8890 - val_accuracy: 0.5897
# Epoch 8/500
#
# Epoch 00008: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 1.0235 - accuracy: 0.5889 - val_loss: 1.0201 - val_accuracy: 0.6667
# Epoch 9/500
#
# Epoch 00009: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 1.0117 - accuracy: 0.5639 - val_loss: 0.9504 - val_accuracy: 0.5385
# Epoch 10/500
#
# Epoch 00010: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.9687 - accuracy: 0.5500 - val_loss: 0.7728 - val_accuracy: 0.6795
# Epoch 11/500
#
# Epoch 00011: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.
# Epoch 119/500
#
# Epoch 00119: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 16ms/step - loss: 0.5017 - accuracy: 0.8083 - val_loss: 0.6128 - val_accuracy: 0.8205
# Epoch 120/500
#
# Epoch 00120: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 16ms/step - loss: 0.4951 - accuracy: 0.7917 - val_loss: 0.5556 - val_accuracy: 0.8077
# Epoch 121/500
#
# Epoch 00121: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4836 - accuracy: 0.7722 - val_loss: 0.6339 - val_accuracy: 0.7949
# Epoch 122/500
#
# Epoch 00122: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4992 - accuracy: 0.7944 - val_loss: 0.8459 - val_accuracy: 0.7564
# Epoch 123/500
#
# Epoch 00123: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 16ms/step - loss: 0.6307 - accuracy: 0.7194 - val_loss: 0.7016 - val_accuracy: 0.7179
# Epoch 124/500
#
# Epoch 00124: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5833 - accuracy: 0.7250 - val_loss: 0.6871 - val_accuracy: 0.8205
# Epoch 125/500
#
# Epoch 00125: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5702 - accuracy: 0.7722 - val_loss: 0.5444 - val_accuracy: 0.7821
# Epoch 126/500
#
# Epoch 00126: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5110 - accuracy: 0.7972 - val_loss: 0.5608 - val_accuracy: 0.7692
# Epoch 127/500
#
# Epoch 00127: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5221 - accuracy: 0.7722 - val_loss: 0.6398 - val_accuracy: 0.7436
# Epoch 128/500
#
# Epoch 00128: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.5008 - accuracy: 0.7806 - val_loss: 0.5910 - val_accuracy: 0.7949
# Epoch 129/500
#
# Epoch 00129: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5072 - accuracy: 0.7917 - val_loss: 0.7487 - val_accuracy: 0.6538
# Epoch 130/500
#
# Epoch 00130: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5509 - accuracy: 0.7333 - val_loss: 0.6107 - val_accuracy: 0.7821
# Epoch 131/500
#
# Epoch 00131: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5125 - accuracy: 0.7750 - val_loss: 0.5513 - val_accuracy: 0.8205
# Epoch 132/500
#
# Epoch 00132: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4879 - accuracy: 0.7889 - val_loss: 0.5073 - val_accuracy: 0.8333
# Epoch 133/500
#
# Epoch 00133: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 19ms/step - loss: 0.4645 - accuracy: 0.7917 - val_loss: 0.5924 - val_accuracy: 0.8077
# Epoch 134/500
#
# Epoch 00134: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4659 - accuracy: 0.7944 - val_loss: 0.6472 - val_accuracy: 0.7564
# Epoch 135/500
#
# Epoch 00135: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4675 - accuracy: 0.7861 - val_loss: 0.5221 - val_accuracy: 0.8205
# Epoch 136/500
#
# Epoch 00136: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4417 - accuracy: 0.8194 - val_loss: 0.6826 - val_accuracy: 0.7564
# Epoch 137/500
#
# Epoch 00137: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4514 - accuracy: 0.8139 - val_loss: 0.4756 - val_accuracy: 0.8462
# Epoch 138/500
#
# Epoch 00138: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4942 - accuracy: 0.8083 - val_loss: 0.8336 - val_accuracy: 0.6410
# Epoch 139/500
#
# Epoch 00139: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5244 - accuracy: 0.7667 - val_loss: 0.6152 - val_accuracy: 0.8205
# Epoch 140/500
#
# Epoch 00140: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4672 - accuracy: 0.7944 - val_loss: 0.8606 - val_accuracy: 0.7436
# Epoch 141/500
#
# Epoch 00141: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5953 - accuracy: 0.7444 - val_loss: 0.8368 - val_accuracy: 0.7564
# Epoch 142/500
#
# Epoch 00142: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5182 - accuracy: 0.7778 - val_loss: 0.6481 - val_accuracy: 0.7692
# Epoch 143/500
#
# Epoch 00143: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4712 - accuracy: 0.7944 - val_loss: 0.5047 - val_accuracy: 0.8205
# Epoch 144/500
#
# Epoch 00144: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4279 - accuracy: 0.8278 - val_loss: 0.5944 - val_accuracy: 0.7564
# Epoch 145/500
#
# Epoch 00145: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.6258 - accuracy: 0.7361 - val_loss: 0.7706 - val_accuracy: 0.7692
# Epoch 146/500
#
# Epoch 00146: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.5504 - accuracy: 0.7639 - val_loss: 0.6132 - val_accuracy: 0.7949
# Epoch 147/500
#
# Epoch 00147: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4860 - accuracy: 0.7889 - val_loss: 0.5777 - val_accuracy: 0.7692
# Epoch 148/500
#
# Epoch 00148: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4795 - accuracy: 0.7944 - val_loss: 0.4877 - val_accuracy: 0.8077
# Epoch 149/500
#
# Epoch 00149: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4669 - accuracy: 0.7889 - val_loss: 0.5828 - val_accuracy: 0.8333
# Epoch 150/500
#
# Epoch 00150: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4290 - accuracy: 0.8139 - val_loss: 0.5531 - val_accuracy: 0.8205
# Epoch 151/500
#
# Epoch 00151: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4161 - accuracy: 0.8278 - val_loss: 0.5293 - val_accuracy: 0.8333
# Epoch 152/500
#
# Epoch 00152: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4290 - accuracy: 0.8194 - val_loss: 0.7758 - val_accuracy: 0.6923
# Epoch 153/500
#
# Epoch 00153: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.6996 - accuracy: 0.7083 - val_loss: 0.4747 - val_accuracy: 0.8590
# Epoch 154/500
#
# Epoch 00154: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.7269 - accuracy: 0.7139 - val_loss: 0.5934 - val_accuracy: 0.7436
# Epoch 155/500
#
# Epoch 00155: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.6235 - accuracy: 0.7139 - val_loss: 0.6401 - val_accuracy: 0.7436
# Epoch 156/500
#
# Epoch 00156: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.6038 - accuracy: 0.7306 - val_loss: 0.6901 - val_accuracy: 0.6795
# Epoch 157/500
#
# Epoch 00157: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5943 - accuracy: 0.7222 - val_loss: 0.7864 - val_accuracy: 0.6538
# Epoch 158/500
#
# Epoch 00158: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5409 - accuracy: 0.7528 - val_loss: 0.6566 - val_accuracy: 0.7949
# Epoch 159/500
#
# Epoch 00159: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4873 - accuracy: 0.7917 - val_loss: 0.7122 - val_accuracy: 0.7436
# Epoch 160/500
#
# Epoch 00160: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4850 - accuracy: 0.7861 - val_loss: 0.5456 - val_accuracy: 0.8333
# Epoch 161/500
#
# Epoch 00161: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4901 - accuracy: 0.7806 - val_loss: 0.5861 - val_accuracy: 0.7949
# Epoch 162/500
#
# Epoch 00162: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4948 - accuracy: 0.7806 - val_loss: 0.6398 - val_accuracy: 0.6923
# Epoch 163/500
#
# Epoch 00163: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5027 - accuracy: 0.7667 - val_loss: 0.6045 - val_accuracy: 0.7949
# Epoch 164/500
#
# Epoch 00164: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4634 - accuracy: 0.8083 - val_loss: 0.6454 - val_accuracy: 0.7692
# Epoch 165/500
#
# Epoch 00165: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4416 - accuracy: 0.8111 - val_loss: 0.5938 - val_accuracy: 0.8077
# Epoch 166/500
#
# Epoch 00166: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4709 - accuracy: 0.7972 - val_loss: 0.5174 - val_accuracy: 0.8462
# Epoch 167/500
#
# Epoch 00167: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4465 - accuracy: 0.8028 - val_loss: 0.5071 - val_accuracy: 0.8462
# Epoch 168/500
#
# Epoch 00168: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4289 - accuracy: 0.8139 - val_loss: 0.5715 - val_accuracy: 0.8205
# Epoch 169/500
#
# Epoch 00169: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4150 - accuracy: 0.8472 - val_loss: 0.7254 - val_accuracy: 0.7564
# Epoch 170/500
#
# Epoch 00170: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4758 - accuracy: 0.7972 - val_loss: 0.6982 - val_accuracy: 0.7949
# Epoch 171/500
#
# Epoch 00171: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5324 - accuracy: 0.7722 - val_loss: 0.5900 - val_accuracy: 0.7436
# Epoch 172/500
#
# Epoch 00172: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4307 - accuracy: 0.8250 - val_loss: 0.4755 - val_accuracy: 0.8333
# Epoch 173/500
#
# Epoch 00173: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4257 - accuracy: 0.8306 - val_loss: 0.5338 - val_accuracy: 0.8077
# Epoch 174/500
#
# Epoch 00174: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4274 - accuracy: 0.8167 - val_loss: 0.6454 - val_accuracy: 0.7564
# Epoch 175/500
#
# Epoch 00175: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4354 - accuracy: 0.8194 - val_loss: 0.5293 - val_accuracy: 0.8590
# Epoch 176/500
#
# Epoch 00176: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4182 - accuracy: 0.8278 - val_loss: 0.5266 - val_accuracy: 0.8205
# Epoch 177/500
#
# Epoch 00177: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3802 - accuracy: 0.8472 - val_loss: 0.6618 - val_accuracy: 0.7949
# Epoch 178/500
#
# Epoch 00178: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3863 - accuracy: 0.8250 - val_loss: 0.7207 - val_accuracy: 0.7949
# Epoch 179/500
#
# Epoch 00179: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4391 - accuracy: 0.8000 - val_loss: 0.5271 - val_accuracy: 0.8077
# Epoch 180/500
#
# Epoch 00180: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4501 - accuracy: 0.8139 - val_loss: 0.4793 - val_accuracy: 0.8205
# Epoch 181/500
#
# Epoch 00181: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4791 - accuracy: 0.7806 - val_loss: 0.6419 - val_accuracy: 0.8077
# Epoch 182/500
#
# Epoch 00182: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.3967 - accuracy: 0.8472 - val_loss: 0.5845 - val_accuracy: 0.8205
# Epoch 183/500
#
# Epoch 00183: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3758 - accuracy: 0.8556 - val_loss: 0.5774 - val_accuracy: 0.8333
# Epoch 184/500
#
# Epoch 00184: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4155 - accuracy: 0.8194 - val_loss: 0.5969 - val_accuracy: 0.8205
# Epoch 185/500
#
# Epoch 00185: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4012 - accuracy: 0.8306 - val_loss: 0.7608 - val_accuracy: 0.7692
# Epoch 186/500
#
# Epoch 00186: LearningRateScheduler setting learning rate to tf.Tensor(0.000181, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4455 - accuracy: 0.8083 - val_loss: 0.6607 - val_accuracy: 0.8462
# Epoch 187/500
#
# Epoch 00187: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4001 - accuracy: 0.8556 - val_loss: 0.4851 - val_accuracy: 0.8333
# Epoch 188/500
#
# Epoch 00188: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3764 - accuracy: 0.8361 - val_loss: 0.5677 - val_accuracy: 0.8462
# Epoch 189/500
#
# Epoch 00189: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3857 - accuracy: 0.8417 - val_loss: 0.5204 - val_accuracy: 0.8333
# Epoch 190/500
#
# Epoch 00190: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3497 - accuracy: 0.8639 - val_loss: 0.5281 - val_accuracy: 0.8462
# Epoch 191/500
#
# Epoch 00191: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.3808 - accuracy: 0.8306 - val_loss: 0.5534 - val_accuracy: 0.7949
# Epoch 192/500
#
# Epoch 00192: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3598 - accuracy: 0.8722 - val_loss: 0.7559 - val_accuracy: 0.8077
# Epoch 193/500
#
# Epoch 00193: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 49ms/step - loss: 0.4033 - accuracy: 0.8472 - val_loss: 0.4977 - val_accuracy: 0.8590
# Epoch 194/500
#
# Epoch 00194: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 74ms/step - loss: 0.3402 - accuracy: 0.8667 - val_loss: 0.5720 - val_accuracy: 0.7949
# Epoch 195/500
#
# Epoch 00195: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3375 - accuracy: 0.8722 - val_loss: 0.5166 - val_accuracy: 0.8333
# Epoch 196/500
#
# Epoch 00196: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3415 - accuracy: 0.8583 - val_loss: 0.6642 - val_accuracy: 0.8205
# Epoch 197/500
#
# Epoch 00197: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.4049 - accuracy: 0.8306 - val_loss: 0.6391 - val_accuracy: 0.7821
# Epoch 198/500
#
# Epoch 00198: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3349 - accuracy: 0.8722 - val_loss: 0.6223 - val_accuracy: 0.7564
# Epoch 199/500
#
# Epoch 00199: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3349 - accuracy: 0.8750 - val_loss: 0.6361 - val_accuracy: 0.8077
# Epoch 200/500
#
# Epoch 00200: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3167 - accuracy: 0.8722 - val_loss: 0.6612 - val_accuracy: 0.7949
# Epoch 201/500
#
# Epoch 00201: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3479 - accuracy: 0.8611 - val_loss: 0.7076 - val_accuracy: 0.7692
# Epoch 202/500
#
# Epoch 00202: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4185 - accuracy: 0.8083 - val_loss: 0.6501 - val_accuracy: 0.7949
# Epoch 203/500
#
# Epoch 00203: LearningRateScheduler setting learning rate to tf.Tensor(0.000161, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3544 - accuracy: 0.8528 - val_loss: 0.4959 - val_accuracy: 0.8333

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
model_deep.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4959 - accuracy: 0.8333
# [0.4959195852279663, 0.8333333134651184]

# %%
model_deep.evaluate(np.array(X_testb_pad),y_testb_encoded)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7822 - accuracy: 0.6667
# [0.782166063785553, 0.6666666865348816]

# %%
y_pred = model_deep.predict(np.array(X_testb_pad))
y_pred_max = np.argsort(y_pred,axis=-1)[:,::-1][:,0]
y_true_max = np.argsort(y_testb_encoded,axis=-1)[:,::-1][:,0]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true_max, y_pred_max, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       murmur       0.82      0.38      0.51        24
#       normal       0.48      0.60      0.53        20
#     extrahls       0.94      0.94      0.94        16
#   extrastole       0.62      0.89      0.73        18
#
#     accuracy                           0.67        78
#    macro avg       0.71      0.70      0.68        78
# weighted avg       0.71      0.67      0.66        78

# %%
m = tf.keras.metrics.AUC(num_thresholds=80)
m.update_state(y_testb_encoded, y_pred)

m.result().numpy()
# Out:
# 0.9020656

# %%
import seaborn as sns

conf = tf.math.confusion_matrix(y_pred_max,y_true_max)

sns.heatmap(conf,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Going deepe 1D CNN

# %%
model_cnn_deep = keras.models.Sequential([
#     tfl.Flatten(input_shape=(40,1)),
    tfl.Conv1D(64,3,activation='relu',padding='same',input_shape=(40,1)),
    tfl.Conv1D(64,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.Conv1D(32,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.Conv1D(16,3,activation='relu',padding='same'),
    tfl.Conv1D(16,3,activation='relu',padding='same'),
    tfl.MaxPool1D(2,2),
    tfl.Flatten(),

    tfl.Dense(64,activation='relu'),
    tfl.Dense(64,activation='relu'),

    tfl.Dense(4,activation='softmax'),

])

model_cnn_deep.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
model_cnn_deep.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 40, 64)            256
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 40, 64)            12352
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 20, 64)            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 20, 32)            6176
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 20, 32)            3104
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 10, 32)            0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 10, 16)            1552
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 10, 16)            784
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 5, 16)             0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 80)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 64)                5184
# _________________________________________________________________
# dense_55 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_56 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 33,828
# Trainable params: 33,828
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_filepath_cnn = '/kaggle/working/checkpoints/cnn_deep'
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 50, mode='min')

checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history=model_cnn_deep.fit(
    x=np.array(x_trainb_pad),
    y=y_trainb_encoded,epochs=500,
    validation_data=(np.array(X_valb_pad),y_valb_encoded),
    callbacks=[lrscheduler,checkpoint,early_stopping]
)
# Out:
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 2s 44ms/step - loss: 1.3022 - accuracy: 0.3833 - val_loss: 0.9316 - val_accuracy: 0.5897
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.9491 - accuracy: 0.5694 - val_loss: 0.8289 - val_accuracy: 0.6410
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.9058 - accuracy: 0.5306 - val_loss: 0.8403 - val_accuracy: 0.6923
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.8827 - accuracy: 0.6000 - val_loss: 0.7848 - val_accuracy: 0.6282
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8174 - accuracy: 0.6028 - val_loss: 0.8659 - val_accuracy: 0.5769
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8412 - accuracy: 0.5972 - val_loss: 0.7962 - val_accuracy: 0.6538
# Epoch 7/500
#
# Epoch 00007: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8186 - accuracy: 0.5944 - val_loss: 0.8114 - val_accuracy: 0.6667
# Epoch 8/500
#
# Epoch 00008: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7939 - accuracy: 0.6361 - val_loss: 0.7491 - val_accuracy: 0.6410
# Epoch 9/500
#
# Epoch 00009: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.7897 - accuracy: 0.6250 - val_loss: 0.7640 - val_accuracy: 0.6923
# Epoch 10/500
#
# Epoch 00010: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7767 - accuracy: 0.6056 - val_loss: 0.7665 - val_accuracy: 0.7051
# Epoch 11/500
#
# Epoch 00011: LearningRateScheduler setting learning rate to tf.Tensor(0.00028100000000000005, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7550 - accuracy: 0.6361 - val_loss: 0.7314 - val_accuracy: 0.6795
# Epoch 12/500
#
# Epoch 00012: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7256 - accuracy: 0.6444 - val_loss: 0.7671 - val_accuracy: 0.6923
# Epoch 13/500
#
# Epoch 00013: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.7287 - accuracy: 0.6833 - val_loss: 0.7180 - val_accuracy: 0.6923
# Epoch 14/500
#
# Epoch 00014: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.7325 - accuracy: 0.6472 - val_loss: 0.7941 - val_accuracy: 0.6410
# Epoch 15/500
#
# Epoch 00015: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7261 - accuracy: 0.6500 - val_loss: 0.7267 - val_accuracy: 0.7051
# Epoch 16/500
#
# Epoch 00016: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6937 - accuracy: 0.6917 - val_loss: 0.6711 - val_accuracy: 0.7436
# Epoch 17/500
#
# Epoch 00017: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.7182 - accuracy: 0.6861 - val_loss: 0.6760 - val_accuracy: 0.7436
# Epoch 18/500
#
# Epoch 00018: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 16ms/step - loss: 0.6721 - accuracy: 0.6972 - val_loss: 0.6498 - val_accuracy: 0.7051
# Epoch 19/500
#
# Epoch 00019: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 18ms/step - loss: 0.6550 - accuracy: 0.7222 - val_loss: 0.6901 - val_accuracy: 0.7564
# Epoch 20/500
#
# Epoch 00020: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6700 - accuracy: 0.6972 - val_loss: 0.6961 - val_accuracy: 0.7436
# Epoch 21/500
#
# Epoch 00021: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6746 - accuracy: 0.7028 - val_loss: 0.6785 - val_accuracy: 0.7436
# Epoch 22/500
#
# Epoch 00022: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6321 - accuracy: 0.7444 - val_loss: 0.6240 - val_accuracy: 0.7692
# Epoch 23/500
#
# Epoch 00023: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6338 - accuracy: 0.7000 - val_loss: 0.6517 - val_accuracy: 0.7564
# Epoch 24/500
#
# Epoch 00024: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6219 - accuracy: 0.7556 - val_loss: 0.6228 - val_accuracy: 0.7692
# Epoch 25/500
#
# Epoch 00025: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6457 - accuracy: 0.7083 - val_loss: 0.6256 - val_accuracy: 0.7692
# Epoch 26/500
#
# Epoch 00026: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.6003 - accuracy: 0.7472 - val_loss: 0.6723 - val_accuracy: 0.7179
# Epoch 27/500
#
# Epoch 00027: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.5636 - accuracy: 0.7750 - val_loss: 0.6307 - val_accuracy: 0.7692
# Epoch 28/500
#
# Epoch 00028: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5467 - accuracy: 0.7778 - val_loss: 0.6395 - val_accuracy: 0.7308
# Epoch 29/500
#
# Epoch 00029: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5399 - accuracy: 0.7833 - val_loss: 0.6247 - val_accuracy: 0.7308
# Epoch 30/500
#
# Epoch 00030: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5559 - accuracy: 0.7556 - val_loss: 0.6294 - val_accuracy: 0.7949
# Epoch 31/500
#
# Epoch 00031: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5465 - accuracy: 0.7778 - val_loss: 0.7009 - val_accuracy: 0.7436
# Epoch 32/500
#
# Epoch 00032: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5521 - accuracy: 0.7639 - val_loss: 0.6569 - val_accuracy: 0.6795
# Epoch 33/500
#
# Epoch 00033: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5492 - accuracy: 0.7528 - val_loss: 0.7852 - val_accuracy: 0.6667
# Epoch 34/500
#
# Epoch 00034: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5525 - accuracy: 0.7667 - val_loss: 0.6821 - val_accuracy: 0.7564
# Epoch 35/500
#
# Epoch 00035: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5411 - accuracy: 0.7750 - val_loss: 0.5833 - val_accuracy: 0.7949
# Epoch 36/500
#
# Epoch 00036: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5038 - accuracy: 0.7944 - val_loss: 0.6242 - val_accuracy: 0.7821
# Epoch 37/500
#
# Epoch 00037: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5028 - accuracy: 0.7861 - val_loss: 0.5721 - val_accuracy: 0.7821
# Epoch 38/500
#
# Epoch 00038: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4765 - accuracy: 0.7972 - val_loss: 0.7613 - val_accuracy: 0.6667
# Epoch 39/500
#
# Epoch 00039: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.4814 - accuracy: 0.8194 - val_loss: 0.5817 - val_accuracy: 0.7692
# Epoch 40/500
#
# Epoch 00040: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.4275 - accuracy: 0.8222 - val_loss: 0.6333 - val_accuracy: 0.7436
# Epoch 41/500
#
# Epoch 00041: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.4247 - accuracy: 0.8389 - val_loss: 0.7679 - val_accuracy: 0.6923
# Epoch 42/500
#
# Epoch 00042: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.5062 - accuracy: 0.7944 - val_loss: 0.6095 - val_accuracy: 0.7179
# Epoch 43/500
#
# Epoch 00043: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4492 - accuracy: 0.8306 - val_loss: 0.5905 - val_accuracy: 0.7692
# Epoch 44/500
#
# Epoch 00044: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4130 - accuracy: 0.8361 - val_loss: 0.5620 - val_accuracy: 0.7692
# Epoch 45/500
#
# Epoch 00045: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3976 - accuracy: 0.8361 - val_loss: 0.5722 - val_accuracy: 0.8077
# Epoch 46/500
#
# Epoch 00046: LearningRateScheduler setting learning rate to tf.Tensor(0.00026100000000000006, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3818 - accuracy: 0.8472 - val_loss: 0.5902 - val_accuracy: 0.7692
# Epoch 47/500
#
# Epoch 00047: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3778 - accuracy: 0.8556 - val_loss: 0.5797 - val_accuracy: 0.7564
# Epoch 48/500
#
# Epoch 00048: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3551 - accuracy: 0.8667 - val_loss: 0.6362 - val_accuracy: 0.7821
# Epoch 49/500
#
# Epoch 00049: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3512 - accuracy: 0.8667 - val_loss: 0.6161 - val_accuracy: 0.8205
# Epoch 50/500
#
# Epoch 00050: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3520 - accuracy: 0.8556 - val_loss: 0.6102 - val_accuracy: 0.7564
# Epoch 51/500
#
# Epoch 00051: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3436 - accuracy: 0.8694 - val_loss: 0.6169 - val_accuracy: 0.7564
# Epoch 52/500
#
# Epoch 00052: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3414 - accuracy: 0.8361 - val_loss: 0.6164 - val_accuracy: 0.7949
# Epoch 53/500
#
# Epoch 00053: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3070 - accuracy: 0.8861 - val_loss: 0.6378 - val_accuracy: 0.7949
# Epoch 54/500
#
# Epoch 00054: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3157 - accuracy: 0.8694 - val_loss: 0.5657 - val_accuracy: 0.7949
# Epoch 55/500
#
# Epoch 00055: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3030 - accuracy: 0.8833 - val_loss: 0.5920 - val_accuracy: 0.7821
# Epoch 56/500
#
# Epoch 00056: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2873 - accuracy: 0.8861 - val_loss: 0.6035 - val_accuracy: 0.7821
# Epoch 57/500
#
# Epoch 00057: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2978 - accuracy: 0.8806 - val_loss: 0.7013 - val_accuracy: 0.7564
# Epoch 58/500
#
# Epoch 00058: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2889 - accuracy: 0.8944 - val_loss: 0.5814 - val_accuracy: 0.7949
# Epoch 59/500
#
# Epoch 00059: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2559 - accuracy: 0.9000 - val_loss: 0.5818 - val_accuracy: 0.8077
# Epoch 60/500
#
# Epoch 00060: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2643 - accuracy: 0.8944 - val_loss: 0.5837 - val_accuracy: 0.8077
# Epoch 61/500
#
# Epoch 00061: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 32ms/step - loss: 0.2453 - accuracy: 0.9056 - val_loss: 0.5999 - val_accuracy: 0.7692
# Epoch 62/500
#
# Epoch 00062: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 36ms/step - loss: 0.2426 - accuracy: 0.8972 - val_loss: 0.5884 - val_accuracy: 0.7949
# Epoch 63/500
#
# Epoch 00063: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 1s 42ms/step - loss: 0.2287 - accuracy: 0.9056 - val_loss: 0.5707 - val_accuracy: 0.8205
# Epoch 64/500
#
# Epoch 00064: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.2352 - accuracy: 0.9111 - val_loss: 0.6004 - val_accuracy: 0.8205
# Epoch 65/500
#
# Epoch 00065: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2306 - accuracy: 0.9167 - val_loss: 0.5958 - val_accuracy: 0.8077
# Epoch 66/500
#
# Epoch 00066: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2200 - accuracy: 0.9056 - val_loss: 0.6181 - val_accuracy: 0.7949
# Epoch 67/500
#
# Epoch 00067: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1959 - accuracy: 0.9361 - val_loss: 0.6774 - val_accuracy: 0.7821
# Epoch 68/500
#
# Epoch 00068: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2067 - accuracy: 0.9167 - val_loss: 0.5887 - val_accuracy: 0.8205
# Epoch 69/500
#
# Epoch 00069: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1845 - accuracy: 0.9361 - val_loss: 0.6465 - val_accuracy: 0.8077
# Epoch 70/500
#
# Epoch 00070: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2013 - accuracy: 0.9278 - val_loss: 0.6186 - val_accuracy: 0.8077
# Epoch 71/500
#
# Epoch 00071: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2123 - accuracy: 0.9167 - val_loss: 0.6980 - val_accuracy: 0.7308
# Epoch 72/500
#
# Epoch 00072: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2147 - accuracy: 0.9194 - val_loss: 0.6246 - val_accuracy: 0.7821
# Epoch 73/500
#
# Epoch 00073: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2048 - accuracy: 0.9222 - val_loss: 0.5983 - val_accuracy: 0.8077
# Epoch 74/500
#
# Epoch 00074: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1946 - accuracy: 0.9306 - val_loss: 0.6572 - val_accuracy: 0.8077
# Epoch 75/500
#
# Epoch 00075: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1658 - accuracy: 0.9500 - val_loss: 0.5561 - val_accuracy: 0.8462
# Epoch 76/500
#
# Epoch 00076: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2013 - accuracy: 0.9028 - val_loss: 0.6098 - val_accuracy: 0.7949
# Epoch 77/500
#
# Epoch 00077: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1461 - accuracy: 0.9500 - val_loss: 0.6112 - val_accuracy: 0.8333
# Epoch 78/500
#
# Epoch 00078: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1445 - accuracy: 0.9472 - val_loss: 0.6213 - val_accuracy: 0.8205
# Epoch 79/500
#
# Epoch 00079: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1292 - accuracy: 0.9694 - val_loss: 0.5989 - val_accuracy: 0.8205
# Epoch 80/500
#
# Epoch 00080: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1355 - accuracy: 0.9722 - val_loss: 0.5821 - val_accuracy: 0.8333
# Epoch 81/500
#
# Epoch 00081: LearningRateScheduler setting learning rate to tf.Tensor(0.00024100000000000003, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1302 - accuracy: 0.9556 - val_loss: 0.5962 - val_accuracy: 0.8333
# Epoch 82/500
#
# Epoch 00082: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1336 - accuracy: 0.9694 - val_loss: 0.6229 - val_accuracy: 0.8077
# Epoch 83/500
#
# Epoch 00083: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1192 - accuracy: 0.9694 - val_loss: 0.6025 - val_accuracy: 0.8333
# Epoch 84/500
#
# Epoch 00084: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1188 - accuracy: 0.9667 - val_loss: 0.5826 - val_accuracy: 0.8333
# Epoch 85/500
#
# Epoch 00085: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1828 - accuracy: 0.9333 - val_loss: 0.7655 - val_accuracy: 0.7692
# Epoch 86/500
#
# Epoch 00086: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1491 - accuracy: 0.9528 - val_loss: 0.5937 - val_accuracy: 0.8333
# Epoch 87/500
#
# Epoch 00087: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1303 - accuracy: 0.9611 - val_loss: 0.6014 - val_accuracy: 0.8462
# Epoch 88/500
#
# Epoch 00088: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1187 - accuracy: 0.9667 - val_loss: 0.6077 - val_accuracy: 0.8205
# Epoch 89/500
#
# Epoch 00089: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0992 - accuracy: 0.9750 - val_loss: 0.5827 - val_accuracy: 0.8333
# Epoch 90/500
#
# Epoch 00090: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1018 - accuracy: 0.9722 - val_loss: 0.6102 - val_accuracy: 0.8333
# Epoch 91/500
#
# Epoch 00091: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0908 - accuracy: 0.9778 - val_loss: 0.6116 - val_accuracy: 0.8333
# Epoch 92/500
#
# Epoch 00092: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1021 - accuracy: 0.9750 - val_loss: 0.6033 - val_accuracy: 0.8333
# Epoch 93/500
#
# Epoch 00093: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1055 - accuracy: 0.9750 - val_loss: 0.6683 - val_accuracy: 0.8205
# Epoch 94/500
#
# Epoch 00094: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0889 - accuracy: 0.9750 - val_loss: 0.6555 - val_accuracy: 0.8333
# Epoch 95/500
#
# Epoch 00095: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0906 - accuracy: 0.9778 - val_loss: 0.6566 - val_accuracy: 0.8205
# Epoch 96/500
#
# Epoch 00096: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0893 - accuracy: 0.9750 - val_loss: 0.6128 - val_accuracy: 0.8333
# Epoch 97/500
#
# Epoch 00097: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0884 - accuracy: 0.9778 - val_loss: 0.6470 - val_accuracy: 0.8333
# Epoch 98/500
#
# Epoch 00098: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0806 - accuracy: 0.9889 - val_loss: 0.6299 - val_accuracy: 0.8333
# Epoch 99/500
#
# Epoch 00099: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0777 - accuracy: 0.9861 - val_loss: 0.6588 - val_accuracy: 0.8333
# Epoch 100/500
#
# Epoch 00100: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0703 - accuracy: 0.9917 - val_loss: 0.6700 - val_accuracy: 0.8077
# Epoch 101/500
#
# Epoch 00101: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0751 - accuracy: 0.9861 - val_loss: 0.6611 - val_accuracy: 0.8333
# Epoch 102/500
#
# Epoch 00102: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0838 - accuracy: 0.9806 - val_loss: 0.6637 - val_accuracy: 0.8333
# Epoch 103/500
#
# Epoch 00103: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0826 - accuracy: 0.9861 - val_loss: 0.7250 - val_accuracy: 0.8205
# Epoch 104/500
#
# Epoch 00104: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1047 - accuracy: 0.9667 - val_loss: 0.7837 - val_accuracy: 0.8077
# Epoch 105/500
#
# Epoch 00105: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0871 - accuracy: 0.9806 - val_loss: 0.6610 - val_accuracy: 0.8590
# Epoch 106/500
#
# Epoch 00106: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0972 - accuracy: 0.9639 - val_loss: 0.6646 - val_accuracy: 0.8205
# Epoch 107/500
#
# Epoch 00107: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0850 - accuracy: 0.9833 - val_loss: 0.8408 - val_accuracy: 0.7949
# Epoch 108/500
#
# Epoch 00108: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0691 - accuracy: 0.9833 - val_loss: 0.6783 - val_accuracy: 0.8462
# Epoch 109/500
#
# Epoch 00109: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0742 - accuracy: 0.9833 - val_loss: 0.6824 - val_accuracy: 0.8205
# Epoch 110/500
#
# Epoch 00110: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0521 - accuracy: 0.9944 - val_loss: 0.7109 - val_accuracy: 0.8205
# Epoch 111/500
#
# Epoch 00111: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0617 - accuracy: 0.9889 - val_loss: 0.7366 - val_accuracy: 0.8077
# Epoch 112/500
#
# Epoch 00112: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9889 - val_loss: 0.7163 - val_accuracy: 0.8205
# Epoch 113/500
#
# Epoch 00113: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0583 - accuracy: 0.9861 - val_loss: 0.6753 - val_accuracy: 0.8333
# Epoch 114/500
#
# Epoch 00114: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0562 - accuracy: 0.9889 - val_loss: 0.7371 - val_accuracy: 0.8077
# Epoch 115/500
#
# Epoch 00115: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0514 - accuracy: 0.9944 - val_loss: 0.7193 - val_accuracy: 0.8205
# Epoch 116/500
#
# Epoch 00116: LearningRateScheduler setting learning rate to tf.Tensor(0.000221, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0450 - accuracy: 0.9972 - val_loss: 0.7143 - val_accuracy: 0.8333
# Epoch 117/500
#
# Epoch 00117: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0447 - accuracy: 0.9944 - val_loss: 0.7208 - val_accuracy: 0.8333
# Epoch 118/500
#
# Epoch 00118: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0423 - accuracy: 0.9944 - val_loss: 0.7522 - val_accuracy: 0.8333
# Epoch 119/500
#
# Epoch 00119: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0415 - accuracy: 0.9944 - val_loss: 0.7413 - val_accuracy: 0.8333
# Epoch 120/500
#
# Epoch 00120: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0406 - accuracy: 0.9972 - val_loss: 0.7283 - val_accuracy: 0.8333
# Epoch 121/500
#
# Epoch 00121: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0468 - accuracy: 0.9944 - val_loss: 0.7701 - val_accuracy: 0.8205
# Epoch 122/500
#
# Epoch 00122: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0404 - accuracy: 0.9944 - val_loss: 0.7587 - val_accuracy: 0.8205
# Epoch 123/500
#
# Epoch 00123: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0425 - accuracy: 0.9944 - val_loss: 0.7769 - val_accuracy: 0.8077
# Epoch 124/500
#
# Epoch 00124: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0423 - accuracy: 0.9944 - val_loss: 0.7846 - val_accuracy: 0.8205
# Epoch 125/500
#
# Epoch 00125: LearningRateScheduler setting learning rate to tf.Tensor(0.000201, shape=(), dtype=float64).
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0623 - accuracy: 0.9889 - val_loss: 0.8390 - val_accuracy: 0.8205

# %%
num=len(history.history['loss'])

plt.plot(range(num),history.history['loss'],label = 'training loss')
plt.plot(range(num),history.history['val_loss'],label = 'validation loss')

plt.legend()

plt.xlabel("Epochs ")
plt.ylabel('Loss')

plt.figure()

plt.plot(range(num),history.history['accuracy'],label = 'training accuracy')
plt.plot(range(num),history.history['val_accuracy'],label = 'validation accuracy')

plt.legend()
plt.xlabel("Epochs ")
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
model_cnn_deep.evaluate(np.array(X_valb_pad),y_valb_encoded)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8390 - accuracy: 0.8205
# [0.8389767408370972, 0.8205128312110901]

# %%
model_cnn_deep.evaluate(np.array(X_testb_pad),y_testb_encoded)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8406 - accuracy: 0.7564
# [0.8406252861022949, 0.7564102411270142]

# %%
y_pred = model_cnn_deep.predict(np.array(X_testb_pad))
y_pred_max = np.argsort(y_pred,axis=-1)[:,::-1][:,0]
y_true_max = np.argsort(y_testb_encoded,axis=-1)[:,::-1][:,0]

# %%
print(classification_report(y_true_max, y_pred_max, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       murmur       0.80      0.67      0.73        24
#       normal       0.60      0.60      0.60        20
#     extrahls       0.94      1.00      0.97        16
#   extrastole       0.71      0.83      0.77        18
#
#     accuracy                           0.76        78
#    macro avg       0.76      0.78      0.77        78
# weighted avg       0.76      0.76      0.75        78

# %%
m = tf.keras.metrics.AUC(num_thresholds=80)
m.update_state(y_testb_encoded, y_pred)

m.result().numpy()
# Out:
# 0.93548656

# %%
conf = tf.math.confusion_matrix(y_pred_max,y_true_max)

sns.heatmap(conf,annot=True)
# Out:
# <AxesSubplot:>
